# %%
import os

# %%
data_path = "/home/cmurphy/datasets/toma/box-detection-coco-1.1"
output_path = "/home/cmurphy/datasets/toma/box-detection-yolo"

# %%
import pandas as pd

train = pd.read_parquet(os.path.join(data_path, "train.parquet"))
val = pd.read_parquet(os.path.join(data_path, "val.parquet"))

# %%
from io import BytesIO
from PIL import Image

CATEGORY_MAP = {
    0: "open",
    1: "closed",
}


def process_object_to_annotation(obj: dict) -> list:
    annotations = []
    for i, box, category in zip(obj["id"], obj["bbox"], obj["category"]):
        annotations.append(
            {
                "category": CATEGORY_MAP.get(category, None),
                "bbox": box,
            }
        )
    return annotations


train["image"] = train["image"].apply(lambda x: Image.open(BytesIO(x)))
train["image_type"] = "image"
train["annotations"] = train["objects"].apply(process_object_to_annotation)
train["label_type"] = "xywh"
train["split"] = "train"

val["image"] = val["image"].apply(lambda x: Image.open(BytesIO(x)))
val["image_type"] = "image"
val["annotations"] = val["objects"].apply(process_object_to_annotation)
val["label_type"] = "xywh"
val["split"] = "val"

dataset = pd.concat([train, val], ignore_index=True)[
    ["image", "image_type", "annotations", "label_type", "split"]
]

# %%
import os
import json
import requests
import base64
import numpy as np
import pandas as pd
from PIL import Image
from io import BytesIO
from tqdm import tqdm
import uuid

"""
Example of using the PrepareYoloData class:

Assuming df_train and df_val are already loaded and have the following columns:
- url: str, the url of the image
- annotations: str, the annotations of the image, which is a list of dicts, 
    - item: {
        "left": int,
        "top": int,
        "width": int,
        "height": int,
        "label": str
    }
df_all = pd.concat([df_train, df_val])
df_all['image'] = df_all['url']
df_all['image_type'] = 'url'
df_all['annotations'] = df_all['annotations'].apply(lambda x_list: [{"category": x['label'], "bbox": [x['left'], x['top'], x['width'], x['height']]} for x in eval(x_list)])
df_all['label_type'] = 'xywh'

PrepareYoloData().process_df(df_all, output_dir="data/custom_dataset")

"""


class PrepareYoloData:
    def _extract_unique_categories(self, df):
        """
        Extract unique category labels from the DataFrame.

        Args:
            df: DataFrame with a "annotations" column containing lists of label dictionaries

        Returns:
            Dictionary mapping category names to category IDs
        """
        unique_labels = set()
        for labels in df["annotations"]:
            if isinstance(labels, list):
                for label in labels:
                    if isinstance(label, dict) and "category" in label:
                        unique_labels.add(label["category"])
                    else:
                        raise ValueError(
                            f"Unrecognized label format: {label}, expecting dict with 'category' and 'bbox'"
                        )
            else:
                raise ValueError(f"Label is not a list of dicts: {labels}")

        return {cat: i + 1 for i, cat in enumerate(sorted(unique_labels))}

    def process_df(self, df, output_dir="yolo_dataset", category_mapping=None):
        """
        Convert a DataFrame with image and label information to COCO format.

        Args:
            df: DataFrame with columns ["image", "annotations", "image_type", "label_type", "split"]
            output_dir: Directory to save the dataset
            annotations is a list of dicts, each dict contains "category" and "bbox"
            category_mapping: Optional dictionary mapping label names to category IDs

        Returns:
            Dictionary containing paths to the created dataset files
        """
        # Collect unique values in split
        unique_splits = df["split"].unique()

        # Create output directories
        os.makedirs(output_dir, exist_ok=True)
        for split in unique_splits:
            os.makedirs(os.path.join(output_dir, "images", split), exist_ok=True)
        os.makedirs(os.path.join(output_dir, "annotations"), exist_ok=True)

        # Initialize COCO format dictionaries for train and val
        coco_data = {
            split: {"images": [], "annotations": [], "categories": []}
            for split in unique_splits
        }

        # Create category list if not provided
        if category_mapping is None:
            category_mapping = self._extract_unique_categories(df)

        # Populate categories in COCO format
        for category_name, category_id in category_mapping.items():
            category_info = {
                "id": category_id,
                "name": category_name,
                "supercategory": "none",
            }
            for split in unique_splits:
                coco_data[split]["categories"].append(category_info)

        # Process each row in the DataFrame
        annotation_id = 1
        for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing images"):
            split = row["split"]
            if split not in unique_splits:
                continue

            # Get image
            image_data = row["image"]
            image_type = row["image_type"]

            # Load image based on type
            if image_type == "url":
                try:
                    response = requests.get(image_data, timeout=10)
                    img = Image.open(BytesIO(response.content))
                except Exception as e:
                    print(f"Error downloading image from URL {image_data}: {e}")
                    continue
            elif image_type == "image_path":
                try:
                    img = Image.open(image_data)
                except Exception as e:
                    print(f"Error opening image from path {image_data}: {e}")
                    continue
            elif image_type == "base64":
                try:
                    img_bytes = base64.b64decode(image_data)
                    img = Image.open(BytesIO(img_bytes))
                except Exception as e:
                    print(f"Error decoding base64 image: {e}")
                    continue
            elif image_type == "image":
                try:
                    img = image_data
                except Exception as e:
                    print(f"Error converting image from array: {e}")
                    continue
            else:
                print(f"Unsupported image type: {image_type}")
                continue

            # Generate a unique filename
            image_id = idx
            file_name = f"{image_id:012d}.jpg"
            img_path = os.path.join(output_dir, "images", split, file_name)

            # Save image
            img = img.convert("RGB")
            img.save(img_path)

            # Get image dimensions
            width, height = img.size

            # Add image info to COCO format
            image_info = {
                "id": image_id,
                "file_name": file_name,
                "width": width,
                "height": height,
                "date_captured": "",
                "license": 1,
                "coco_url": "",
                "flickr_url": "",
            }
            coco_data[split]["images"].append(image_info)

            # Process labels
            annotations = row["annotations"]
            if not isinstance(annotations, list):
                continue

            for annotation in annotations:
                if not isinstance(annotation, dict) or (
                    "category" not in annotation or "bbox" not in annotation
                ):
                    raise ValueError(
                        f"Unrecognized label format: {annotation}, expecting dict with 'category' and 'bbox'"
                    )

                category_name = annotation["category"]
                if category_name not in category_mapping:
                    raise ValueError(f"Unrecognized category: {category_name}")

                category_id = category_mapping[category_name]
                bbox = annotation["bbox"]

                # Convert bbox based on label_type
                label_type = row["label_type"]
                if label_type == "xyxy":
                    # [x1, y1, x2, y2] to COCO [x, y, width, height]
                    x1, y1, x2, y2 = bbox
                    x, y = x1, y1
                    w, h = x2 - x1, y2 - y1
                elif label_type == "xywh":
                    # [x, y, w, h] to COCO [x, y, width, height]
                    x, y, w, h = bbox
                else:
                    print(f"Unsupported label type: {label_type}")
                    continue

                # Create segmentation (simple polygon from bbox)

                segmentation = [[x, y, x + w, y, x + w, y + h, x, y + h]]
                segmentation = [[float(p) for p in segmentation[0]]]

                # Calculate area
                area = w * h

                # Add annotation to COCO format
                annotation_info = {
                    "id": annotation_id,
                    "image_id": image_id,
                    "category_id": category_id,
                    "bbox": [float(x), float(y), float(w), float(h)],
                    "area": float(area),
                    "segmentation": segmentation,
                    "iscrowd": 0,
                }
                coco_data[split]["annotations"].append(annotation_info)
                annotation_id += 1

        # Save COCO format annotations
        train_json_path = os.path.join(
            output_dir, "annotations", "instances_train.json"
        )
        val_json_path = os.path.join(output_dir, "annotations", "instances_val.json")

        with open(train_json_path, "w") as f:
            json.dump(coco_data["train"], f)

        with open(val_json_path, "w") as f:
            json.dump(coco_data["val"], f)

        return {
            "train_images": os.path.join(output_dir, "images", "train"),
            "val_images": os.path.join(output_dir, "images", "val"),
            "train_annotations": train_json_path,
            "val_annotations": val_json_path,
        }

# %%
PrepareYoloData().process_df(
    dataset, output_dir=output_path, category_mapping={"open": 0, "closed": 1}
)
# Out:
# Processing images: 100%|██████████| 7709/7709 [00:11<00:00, 684.29it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 PrepareYoloData().process_df(
#       2     dataset, output_dir=output_path, category_mapping={"open": 0, "closed": 1}
#       3 )
#
# Cell In[35], line 232, in PrepareYoloData.process_df(self, df, output_dir, category_mapping)
#     229 val_json_path = os.path.join(output_dir, "annotations", "instances_val.json")
#     231 with open(train_json_path, "w") as f:
# --> 232     json.dump(coco_data["train"], f)
#     234 with open(val_json_path, "w") as f:
#     235     json.dump(coco_data["val"], f)
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File ~/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type int64 is not JSON serializable

# %%
import json

with open(os.path.join(output_path, "annotations", "instances_train.json")) as f:
    train_data = json.load(f)

# %%
train_data["annotations"]
# Out:
# [{'id': 1,
#   'image_id': 0,
#   'category_id': 1,
#   'bbox': [350.0, 222.0, 109.0, 46.0],
#   'area': 5014.0,
#   'segmentation': [[0.546875,
#     0.4625,
#     0.7171875,
#     0.4625,
#     0.7171875,
#     0.5583333333333333,
#     0.546875,
#     0.5583333333333333]],
#   'iscrowd': 0},
#  {'id': 2,
#   'image_id': 1,
#   'category_id': 1,
#   'bbox': [135.0, 160.0, 419.0, 257.0],
#   'area': 107683.0,
#   'segmentation': [[0.2109375,
#     0.3333333333333333,
#     0.865625,
#     0.3333333333333333,
#     0.865625,
#     0.86875,
#     0.2109375,
#     0.86875]],
#   'iscrowd': 0},
#  {'id': 3,
#   'image_id': 2,
#   'category_id': 0,
#   'bbox': [90.0, 9.0, 464.0, 471.0],
#   'area': 218544.0,
#   'segmentation': [[0.140625,
#     0.01875,
#     0.865625,
#     0.01875,
#     0.865625,
#     1.0,
#     0.140625,
#     1.0]],
#   'iscrowd': 0},
#  {'id': 4,
#   'image_id': 3,
#   'category_id': 1,
#   'bbox': [0.0, 90.0, 638.0, 456.0],
#   'area': 290928.0,
#   'segmentation': [[0.0,
#     0.140625,
#     0.996875,
#     0.140625,
#     0.996875,
#     0.853125,
#     0.0,
#     0.853125]],
#   'iscrowd': 0},
#  {'id': 5,
#   'image_id': 4,
#   'category_id': 0,
#   'bbox': [176.0, 202.0, 134.0, 252.0],
#   'area': 33768.0,
#   'segmentation': [[0.275,
#     0.42083333333333334,
#     0.484375,
#     0.42083333333333334,
#     0.484375,
#     0.9458333333333333,
#     0.275,
#     0.9458333333333333]],
#   'iscrowd': 0},
#  {'id': 6,
#   'image_id': 5,
#   'category_id': 0,
#   'bbox': [0.0, 63.0, 463.0, 356.0],
#   'area': 164828.0,
#   'segmentation': [[0.0,
#     0.13125,
#     0.7234375,
#     0.13125,
#     0.7234375,
#     0.8729166666666667,
#     0.0,
#     0.8729166666666667]],
#   'iscrowd': 0},
#  {'id': 7,
#   'image_id': 6,
#   'category_id': 1,
#   'bbox': [416.0, 174.0, 136.0, 57.0],
#   'area': 7752.0,
#   'segmentation': [[0.65,
#     0.3625,
#     0.8625,
#     0.3625,
#     0.8625,
#     0.48125,
#     0.65,
#     0.48125]],
#   'iscrowd': 0},
#  {'id': 8,
#   'image_id': 7,
#   'category_id': 0,
#   'bbox': [313.0, 145.0, 73.0, 45.0],
#   'area': 3285.0,
#   'segmentation': [[0.4890625,
#     0.3020833333333333,
#     0.603125,
#     0.3020833333333333,
#     0.603125,
#     0.3958333333333333,
#     0.4890625,
#     0.3958333333333333]],
#   'iscrowd': 0},
#  {'id': 9,
#   'image_id': 7,
#   'category_id': 1,
#   'bbox': [22.0, 106.0, 44.0, 21.0],
#   'area': 924.0,
#   'segmentation': [[0.034375,
#     0.22083333333333333,
#     0.103125,
#     0.22083333333333333,
#     0.103125,
#     0.26458333333333334,
#     0.034375,
#     0.26458333333333334]],
#   'iscrowd': 0},
#  {'id': 10,
#   'image_id': 8,
#   'category_id': 0,
#   'bbox': [127.0, 229.0, 187.0, 116.0],
#   'area': 21692.0,
#   'segmentation': [[0.1984375,
#     0.47708333333333336,
#     0.490625,
#     0.47708333333333336,
#     0.490625,
#     0.71875,
#     0.1984375,
#     0.71875]],
#   'iscrowd': 0},
#  {'id': 11,
#   'image_id': 9,
#   'category_id': 1,
#   'bbox': [210.0, 167.0, 127.0, 47.0],
#   'area': 5969.0,
#   'segmentation': [[0.328125,
#     0.34791666666666665,
#     0.5265625,
#     0.34791666666666665,
#     0.5265625,
#     0.44583333333333336,
#     0.328125,
#     0.44583333333333336]],
#   'iscrowd': 0},
#  {'id': 12,
#   'image_id': 10,
#   'category_id': 1,
#   'bbox': [150.0, 125.0, 326.0, 113.0],
#   'area': 36838.0,
#   'segmentation': [[0.234375,
#     0.2604166666666667,
#     0.74375,
#     0.2604166666666667,
#     0.74375,
#     0.49583333333333335,
#     0.234375,
#     0.49583333333333335]],
#   'iscrowd': 0},
#  {'id': 13,
#   'image_id': 11,
#   'category_id': 1,
#   'bbox': [180.0, 167.0, 185.0, 61.0],
#   'area': 11285.0,
#   'segmentation': [[0.28125,
#     0.34791666666666665,
#     0.5703125,
#     0.34791666666666665,
#     0.5703125,
#     0.475,
#     0.28125,
#     0.475]],
#   'iscrowd': 0},
#  {'id': 14,
#   'image_id': 12,
#   'category_id': 1,
#   'bbox': [152.0, 88.0, 156.0, 113.0],
#   'area': 17628.0,
#   'segmentation': [[0.2375,
#     0.18333333333333332,
#     0.48125,
#     0.18333333333333332,
#     0.48125,
#     0.41875,
#     0.2375,
#     0.41875]],
#   'iscrowd': 0},
#  {'id': 15,
#   'image_id': 13,
#   'category_id': 0,
#   'bbox': [155.0, 163.0, 289.0, 98.0],
#   'area': 28322.0,
#   'segmentation': [[0.2421875,
#     0.33958333333333335,
#     0.69375,
#     0.33958333333333335,
#     0.69375,
#     0.54375,
#     0.2421875,
#     0.54375]],
#   'iscrowd': 0},
#  {'id': 16,
#   'image_id': 14,
#   'category_id': 1,
#   'bbox': [184.0, 52.0, 281.0, 201.0],
#   'area': 56481.0,
#   'segmentation': [[0.2875,
#     0.10833333333333334,
#     0.7265625,
#     0.10833333333333334,
#     0.7265625,
#     0.5270833333333333,
#     0.2875,
#     0.5270833333333333]],
#   'iscrowd': 0},
#  {'id': 17,
#   'image_id': 14,
#   'category_id': 1,
#   'bbox': [170.0, 201.0, 324.0, 265.0],
#   'area': 85860.0,
#   'segmentation': [[0.265625,
#     0.41875,
#     0.771875,
#     0.41875,
#     0.771875,
#     0.9708333333333333,
#     0.265625,
#     0.9708333333333333]],
#   'iscrowd': 0},
#  {'id': 18,
#   'image_id': 15,
#   'category_id': 0,
#   'bbox': [6.0, 106.0, 450.0, 313.0],
#   'area': 140850.0,
#   'segmentation': [[0.009375,
#     0.22083333333333333,
#     0.7125,
#     0.22083333333333333,
#     0.7125,
#     0.8729166666666667,
#     0.009375,
#     0.8729166666666667]],
#   'iscrowd': 0},
#  {'id': 19,
#   'image_id': 16,
#   'category_id': 1,
#   'bbox': [173.0, 290.0, 49.0, 110.0],
#   'area': 5390.0,
#   'segmentation': [[0.2703125,
#     0.6041666666666666,
#     0.346875,
#     0.6041666666666666,
#     0.346875,
#     0.8333333333333334,
#     0.2703125,
#     0.8333333333333334]],
#   'iscrowd': 0},
#  {'id': 20,
#   'image_id': 17,
#   'category_id': 1,
#   'bbox': [178.0, 265.0, 160.0, 64.0],
#   'area': 10240.0,
#   'segmentation': [[0.278125,
#     0.5520833333333334,
#     0.528125,
#     0.5520833333333334,
#     0.528125,
#     0.6854166666666667,
#     0.278125,
#     0.6854166666666667]],
#   'iscrowd': 0},
#  {'id': 21,
#   'image_id': 18,
#   'category_id': 1,
#   'bbox': [108.0, 38.0, 428.0, 377.0],
#   'area': 161356.0,
#   'segmentation': [[0.16875,
#     0.07916666666666666,
#     0.8375,
#     0.07916666666666666,
#     0.8375,
#     0.8645833333333334,
#     0.16875,
#     0.8645833333333334]],
#   'iscrowd': 0},
#  {'id': 22,
#   'image_id': 19,
#   'category_id': 0,
#   'bbox': [14.0, 137.0, 626.0, 294.0],
#   'area': 184044.0,
#   'segmentation': [[0.021875,
#     0.28541666666666665,
#     1.0,
#     0.28541666666666665,
#     1.0,
#     0.8979166666666667,
#     0.021875,
#     0.8979166666666667]],
#   'iscrowd': 0},
#  {'id': 23,
#   'image_id': 20,
#   'category_id': 1,
#   'bbox': [221.0, 91.0, 174.0, 60.0],
#   'area': 10440.0,
#   'segmentation': [[0.3453125,
#     0.18958333333333333,
#     0.6171875,
#     0.18958333333333333,
#     0.6171875,
#     0.3145833333333333,
#     0.3453125,
#     0.3145833333333333]],
#   'iscrowd': 0},
#  {'id': 24,
#   'image_id': 21,
#   'category_id': 1,
#   'bbox': [169.0, 255.0, 188.0, 136.0],
#   'area': 25568.0,
#   'segmentation': [[0.2640625,
#     0.53125,
#     0.5578125,
#     0.53125,
#     0.5578125,
#     0.8145833333333333,
#     0.2640625,
#     0.8145833333333333]],
#   'iscrowd': 0},
#  {'id': 25,
#   'image_id': 21,
#   'category_id': 0,
#   'bbox': [137.0, 120.0, 272.0, 167.0],
#   'area': 45424.0,
#   'segmentation': [[0.2140625,
#     0.25,
#     0.6390625,
#     0.25,
#     0.6390625,
#     0.5979166666666667,
#     0.2140625,
#     0.5979166666666667]],
#   'iscrowd': 0},
#  {'id': 26,
#   'image_id': 22,
#   'category_id': 1,
#   'bbox': [342.0, 131.0, 155.0, 55.0],
#   'area': 8525.0,
#   'segmentation': [[0.534375,
#     0.27291666666666664,
#     0.7765625,
#     0.27291666666666664,
#     0.7765625,
#     0.3875,
#     0.534375,
#     0.3875]],
#   'iscrowd': 0},
#  {'id': 27,
#   'image_id': 23,
#   'category_id': 1,
#   'bbox': [91.0, 53.0, 455.0, 368.0],
#   'area': 167440.0,
#   'segmentation': [[0.1421875,
#     0.11041666666666666,
#     0.853125,
#     0.11041666666666666,
#     0.853125,
#     0.8770833333333333,
#     0.1421875,
#     0.8770833333333333]],
#   'iscrowd': 0},
#  {'id': 28,
#   'image_id': 24,
#   'category_id': 1,
#   'bbox': [280.0, 228.0, 162.0, 71.0],
#   'area': 11502.0,
#   'segmentation': [[0.4375,
#     0.475,
#     0.690625,
#     0.475,
#     0.690625,
#     0.6229166666666667,
#     0.4375,
#     0.6229166666666667]],
#   'iscrowd': 0},
#  {'id': 29,
#   'image_id': 25,
#   'category_id': 1,
#   'bbox': [205.0, 23.0, 219.0, 408.0],
#   'area': 89352.0,
#   'segmentation': [[0.3203125,
#     0.04791666666666667,
#     0.6625,
#     0.04791666666666667,
#     0.6625,
#     0.8979166666666667,
#     0.3203125,
#     0.8979166666666667]],
#   'iscrowd': 0},
#  {'id': 30,
#   'image_id': 26,
#   'category_id': 0,
#   'bbox': [273.0, 163.0, 150.0, 83.0],
#   'area': 12450.0,
#   'segmentation': [[0.4265625,
#     0.33958333333333335,
#     0.6609375,
#     0.33958333333333335,
#     0.6609375,
#     0.5125,
#     0.4265625,
#     0.5125]],
#   'iscrowd': 0},
#  {'id': 31,
#   'image_id': 26,
#   'category_id': 1,
#   'bbox': [0.0, 146.0, 24.0, 22.0],
#   'area': 528.0,
#   'segmentation': [[0.0,
#     0.30416666666666664,
#     0.0375,
#     0.30416666666666664,
#     0.0375,
#     0.35,
#     0.0,
#     0.35]],
#   'iscrowd': 0},
#  {'id': 32,
#   'image_id': 27,
#   'category_id': 0,
#   'bbox': [464.0, 7.0, 175.0, 92.0],
#   'area': 16100.0,
#   'segmentation': [[0.725,
#     0.014583333333333334,
#     0.9984375,
#     0.014583333333333334,
#     0.9984375,
#     0.20625,
#     0.725,
#     0.20625]],
#   'iscrowd': 0},
#  {'id': 33,
#   'image_id': 28,
#   'category_id': 0,
#   'bbox': [162.0, 155.0, 271.0, 204.0],
#   'area': 55284.0,
#   'segmentation': [[0.253125,
#     0.3229166666666667,
#     0.6765625,
#     0.3229166666666667,
#     0.6765625,
#     0.7479166666666667,
#     0.253125,
#     0.7479166666666667]],
#   'iscrowd': 0},
#  {'id': 34,
#   'image_id': 29,
#   'category_id': 1,
#   'bbox': [365.0, 214.0, 190.0, 77.0],
#   'area': 14630.0,
#   'segmentation': [[0.5703125,
#     0.44583333333333336,
#     0.8671875,
#     0.44583333333333336,
#     0.8671875,
#     0.60625,
#     0.5703125,
#     0.60625]],
#   'iscrowd': 0},
#  {'id': 35,
#   'image_id': 30,
#   'category_id': 1,
#   'bbox': [62.0, 114.0, 152.0, 56.0],
#   'area': 8512.0,
#   'segmentation': [[0.096875,
#     0.2375,
#     0.334375,
#     0.2375,
#     0.334375,
#     0.3541666666666667,
#     0.096875,
#     0.3541666666666667]],
#   'iscrowd': 0},
#  {'id': 36,
#   'image_id': 31,
#   'category_id': 0,
#   'bbox': [93.0, 32.0, 410.0, 280.0],
#   'area': 114800.0,
#   'segmentation': [[0.1453125,
#     0.06666666666666667,
#     0.7859375,
#     0.06666666666666667,
#     0.7859375,
#     0.65,
#     0.1453125,
#     0.65]],
#   'iscrowd': 0},
#  {'id': 37,
#   'image_id': 32,
#   'category_id': 1,
#   'bbox': [200.0, 81.0, 230.0, 65.0],
#   'area': 14950.0,
#   'segmentation': [[0.3125,
#     0.16875,
#     0.671875,
#     0.16875,
#     0.671875,
#     0.30416666666666664,
#     0.3125,
#     0.30416666666666664]],
#   'iscrowd': 0},
#  {'id': 38,
#   'image_id': 33,
#   'category_id': 0,
#   'bbox': [237.0, 105.0, 300.0, 130.0],
#   'area': 39000.0,
#   'segmentation': [[0.3703125,
#     0.21875,
#     0.8390625,
#     0.21875,
#     0.8390625,
#     0.4895833333333333,
#     0.3703125,
#     0.4895833333333333]],
#   'iscrowd': 0},
#  {'id': 39,
#   'image_id': 34,
#   'category_id': 0,
#   'bbox': [0.0, 154.0, 375.0, 265.0],
#   'area': 99375.0,
#   'segmentation': [[0.0,
#     0.32083333333333336,
#     0.5859375,
#     0.32083333333333336,
#     0.5859375,
#     0.8729166666666667,
#     0.0,
#     0.8729166666666667]],
#   'iscrowd': 0},
#  {'id': 40,
#   'image_id': 35,
#   'category_id': 1,
#   'bbox': [490.0, 182.0, 111.0, 54.0],
#   'area': 5994.0,
#   'segmentation': [[0.765625,
#     0.37916666666666665,
#     0.9390625,
#     0.37916666666666665,
#     0.9390625,
#     0.49166666666666664,
#     0.765625,
#     0.49166666666666664]],
#   'iscrowd': 0},
#  {'id': 41,
#   'image_id': 36,
#   'category_id': 1,
#   'bbox': [709.0, 121.0, 138.0, 122.0],
#   'area': 16836.0,
#   'segmentation': [[0.6923828125,
#     0.236328125,
#     0.8271484375,
#     0.236328125,
#     0.8271484375,
#     0.474609375,
#     0.6923828125,
#     0.474609375]],
#   'iscrowd': 0},
#  {'id': 42,
#   'image_id': 37,
#   'category_id': 1,
#   'bbox': [332.0, 259.0, 171.0, 88.0],
#   'area': 15048.0,
#   'segmentation': [[0.51875,
#     0.5395833333333333,
#     0.7859375,
#     0.5395833333333333,
#     0.7859375,
#     0.7229166666666667,
#     0.51875,
#     0.7229166666666667]],
#   'iscrowd': 0},
#  {'id': 43,
#   'image_id': 38,
#   'category_id': 0,
#   'bbox': [154.0, 24.0, 214.0, 419.0],
#   'area': 89666.0,
#   'segmentation': [[0.240625,
#     0.05,
#     0.575,
#     0.05,
#     0.575,
#     0.9229166666666667,
#     0.240625,
#     0.9229166666666667]],
#   'iscrowd': 0},
#  {'id': 44,
#   'image_id': 39,
#   'category_id': 1,
#   'bbox': [194.0, 178.0, 150.0, 46.0],
#   'area': 6900.0,
#   'segmentation': [[0.303125,
#     0.37083333333333335,
#     0.5375,
#     0.37083333333333335,
#     0.5375,
#     0.4666666666666667,
#     0.303125,
#     0.4666666666666667]],
#   'iscrowd': 0},
#  {'id': 45,
#   'image_id': 40,
#   'category_id': 0,
#   'bbox': [107.0, 0.0, 470.0, 202.0],
#   'area': 94940.0,
#   'segmentation': [[0.1671875,
#     0.0,
#     0.9015625,
#     0.0,
#     0.9015625,
#     0.42083333333333334,
#     0.1671875,
#     0.42083333333333334]],
#   'iscrowd': 0},
#  {'id': 46,
#   'image_id': 41,
#   'category_id': 1,
#   'bbox': [263.0, 243.0, 124.0, 49.0],
#   'area': 6076.0,
#   'segmentation': [[0.4109375,
#     0.50625,
#     0.6046875,
#     0.50625,
#     0.6046875,
#     0.6083333333333333,
#     0.4109375,
#     0.6083333333333333]],
#   'iscrowd': 0},
#  {'id': 47,
#   'image_id': 42,
#   'category_id': 0,
#   'bbox': [76.0, 110.0, 547.0, 370.0],
#   'area': 202390.0,
#   'segmentation': [[0.11875,
#     0.22916666666666666,
#     0.9734375,
#     0.22916666666666666,
#     0.9734375,
#     1.0,
#     0.11875,
#     1.0]],
#   'iscrowd': 0},
#  {'id': 48,
#   'image_id': 43,
#   'category_id': 0,
#   'bbox': [0.0, 117.0, 461.0, 315.0],
#   'area': 145215.0,
#   'segmentation': [[0.0,
#     0.24375,
#     0.7203125,
#     0.24375,
#     0.7203125,
#     0.9,
#     0.0,
#     0.9]],
#   'iscrowd': 0},
#  {'id': 49,
#   'image_id': 44,
#   'category_id': 1,
#   'bbox': [54.0, 125.0, 514.0, 268.0],
#   'area': 137752.0,
#   'segmentation': [[0.084375,
#     0.2604166666666667,
#     0.8875,
#     0.2604166666666667,
#     0.8875,
#     0.81875,
#     0.084375,
#     0.81875]],
#   'iscrowd': 0},
#  {'id': 50,
#   'image_id': 45,
#   'category_id': 0,
#   'bbox': [27.0, 9.0, 613.0, 470.0],
#   'area': 288110.0,
#   'segmentation': [[0.0421875,
#     0.01875,
#     1.0,
#     0.01875,
#     1.0,
#     0.9979166666666667,
#     0.0421875,
#     0.9979166666666667]],
#   'iscrowd': 0},
#  {'id': 51,
#   'image_id': 46,
#   'category_id': 1,
#   'bbox': [80.0, 65.0, 486.0, 344.0],
#   'area': 167184.0,
#   'segmentation': [[0.125,
#     0.13541666666666666,
#     0.884375,
#     0.13541666666666666,
#     0.884375,
#     0.8520833333333333,
#     0.125,
#     0.8520833333333333]],
#   'iscrowd': 0},
#  {'id': 52,
#   'image_id': 47,
#   'category_id': 1,
#   'bbox': [345.0, 89.0, 153.0, 63.0],
#   'area': 9639.0,
#   'segmentation': [[0.5390625,
#     0.18541666666666667,
#     0.778125,
#     0.18541666666666667,
#     0.778125,
#     0.31666666666666665,
#     0.5390625,
#     0.31666666666666665]],
#   'iscrowd': 0},
#  {'id': 53,
#   'image_id': 48,
#   'category_id': 1,
#   'bbox': [122.0, 106.0, 187.0, 86.0],
#   'area': 16082.0,
#   'segmentation': [[0.190625,
#     0.22083333333333333,
#     0.4828125,
#     0.22083333333333333,
#     0.4828125,
#     0.4,
#     0.190625,
#     0.4]],
#   'iscrowd': 0},
#  {'id': 54,
#   'image_id': 49,
#   'category_id': 0,
#   'bbox': [252.0, 56.0, 192.0, 393.0],
#   'area': 75456.0,
#   'segmentation': [[0.39375,
#     0.11666666666666667,
#     0.69375,
#     0.11666666666666667,
#     0.69375,
#     0.9354166666666667,
#     0.39375,
#     0.9354166666666667]],
#   'iscrowd': 0},
#  {'id': 55,
#   'image_id': 50,
#   'category_id': 1,
#   'bbox': [169.0, 110.0, 149.0, 60.0],
#   'area': 8940.0,
#   'segmentation': [[0.2640625,
#     0.22916666666666666,
#     0.496875,
#     0.22916666666666666,
#     0.496875,
#     0.3541666666666667,
#     0.2640625,
#     0.3541666666666667]],
#   'iscrowd': 0},
#  {'id': 56,
#   'image_id': 51,
#   'category_id': 1,
#   'bbox': [349.0, 112.0, 104.0, 215.0],
#   'area': 22360.0,
#   'segmentation': [[0.5453125,
#     0.23333333333333334,
#     0.7078125,
#     0.23333333333333334,
#     0.7078125,
#     0.68125,
#     0.5453125,
#     0.68125]],
#   'iscrowd': 0},
#  {'id': 57,
#   'image_id': 51,
#   'category_id': 1,
#   'bbox': [404.0, 14.0, 143.0, 268.0],
#   'area': 38324.0,
#   'segmentation': [[0.63125,
#     0.029166666666666667,
#     0.8546875,
#     0.029166666666666667,
#     0.8546875,
#     0.5875,
#     0.63125,
#     0.5875]],
#   'iscrowd': 0},
#  {'id': 58,
#   'image_id': 51,
#   'category_id': 1,
#   'bbox': [268.0, 242.0, 251.0, 197.0],
#   'area': 49447.0,
#   'segmentation': [[0.41875,
#     0.5041666666666667,
#     0.8109375,
#     0.5041666666666667,
#     0.8109375,
#     0.9145833333333333,
#     0.41875,
#     0.9145833333333333]],
#   'iscrowd': 0},
#  {'id': 59,
#   'image_id': 51,
#   'category_id': 1,
#   'bbox': [260.0, 43.0, 115.0, 234.0],
#   'area': 26910.0,
#   'segmentation': [[0.40625,
#     0.08958333333333333,
#     0.5859375,
#     0.08958333333333333,
#     0.5859375,
#     0.5770833333333333,
#     0.40625,
#     0.5770833333333333]],
#   'iscrowd': 0},
#  {'id': 60,
#   'image_id': 51,
#   'category_id': 1,
#   'bbox': [133.0, 61.0, 118.0, 153.0],
#   'area': 18054.0,
#   'segmentation': [[0.2078125,
#     0.12708333333333333,
#     0.3921875,
#     0.12708333333333333,
#     0.3921875,
#     0.44583333333333336,
#     0.2078125,
#     0.44583333333333336]],
#   'iscrowd': 0},
#  {'id': 61,
#   'image_id': 51,
#   'category_id': 1,
#   'bbox': [87.0, 173.0, 182.0, 275.0],
#   'area': 50050.0,
#   'segmentation': [[0.1359375,
#     0.36041666666666666,
#     0.4203125,
#     0.36041666666666666,
#     0.4203125,
#     0.9333333333333333,
#     0.1359375,
#     0.9333333333333333]],
#   'iscrowd': 0},
#  {'id': 62,
#   'image_id': 52,
#   'category_id': 0,
#   'bbox': [95.0, 84.0, 444.0, 323.0],
#   'area': 143412.0,
#   'segmentation': [[0.1484375,
#     0.175,
#     0.8421875,
#     0.175,
#     0.8421875,
#     0.8479166666666667,
#     0.1484375,
#     0.8479166666666667]],
#   'iscrowd': 0},
#  {'id': 63,
#   'image_id': 53,
#   'category_id': 1,
#   'bbox': [240.0, 236.0, 117.0, 49.0],
#   'area': 5733.0,
#   'segmentation': [[0.375,
#     0.49166666666666664,
#     0.5578125,
#     0.49166666666666664,
#     0.5578125,
#     0.59375,
#     0.375,
#     0.59375]],
#   'iscrowd': 0},
#  {'id': 64,
#   'image_id': 54,
#   'category_id': 1,
#   'bbox': [237.0, 255.0, 129.0, 71.0],
#   'area': 9159.0,
#   'segmentation': [[0.3703125,
#     0.53125,
#     0.571875,
#     0.53125,
#     0.571875,
#     0.6791666666666667,
#     0.3703125,
#     0.6791666666666667]],
#   'iscrowd': 0},
#  {'id': 65,
#   'image_id': 55,
#   'category_id': 0,
#   'bbox': [95.0, 65.0, 416.0, 244.0],
#   'area': 101504.0,
#   'segmentation': [[0.1484375,
#     0.13541666666666666,
#     0.7984375,
#     0.13541666666666666,
#     0.7984375,
#     0.64375,
#     0.1484375,
#     0.64375]],
#   'iscrowd': 0},
#  {'id': 66,
#   'image_id': 56,
#   'category_id': 0,
#   'bbox': [166.0, 118.0, 297.0, 307.0],
#   'area': 91179.0,
#   'segmentation': [[0.259375,
#     0.24583333333333332,
#     0.7234375,
#     0.24583333333333332,
#     0.7234375,
#     0.8854166666666666,
#     0.259375,
#     0.8854166666666666]],
#   'iscrowd': 0},
#  {'id': 67,
#   'image_id': 57,
#   'category_id': 1,
#   'bbox': [391.0, 82.0, 44.0, 28.0],
#   'area': 1232.0,
#   'segmentation': [[0.6109375,
#     0.17083333333333334,
#     0.6796875,
#     0.17083333333333334,
#     0.6796875,
#     0.22916666666666666,
#     0.6109375,
#     0.22916666666666666]],
#   'iscrowd': 0},
#  {'id': 68,
#   'image_id': 58,
#   'category_id': 0,
#   'bbox': [83.0, 30.0, 493.0, 405.0],
#   'area': 199665.0,
#   'segmentation': [[0.1296875,
#     0.0625,
#     0.9,
#     0.0625,
#     0.9,
#     0.90625,
#     0.1296875,
#     0.90625]],
#   'iscrowd': 0},
#  {'id': 69,
#   'image_id': 59,
#   'category_id': 1,
#   'bbox': [76.0, 157.0, 189.0, 80.0],
#   'area': 15120.0,
#   'segmentation': [[0.11875,
#     0.32708333333333334,
#     0.4140625,
#     0.32708333333333334,
#     0.4140625,
#     0.49375,
#     0.11875,
#     0.49375]],
#   'iscrowd': 0},
#  {'id': 70,
#   'image_id': 60,
#   'category_id': 1,
#   'bbox': [0.0, 16.0, 639.0, 584.0],
#   'area': 373176.0,
#   'segmentation': [[0.0,
#     0.025,
#     0.9984375,
#     0.025,
#     0.9984375,
#     0.9375,
#     0.0,
#     0.9375]],
#   'iscrowd': 0},
#  {'id': 71,
#   'image_id': 61,
#   'category_id': 0,
#   'bbox': [90.0, 102.0, 432.0, 275.0],
#   'area': 118800.0,
#   'segmentation': [[0.140625,
#     0.2125,
#     0.815625,
#     0.2125,
#     0.815625,
#     0.7854166666666667,
#     0.140625,
#     0.7854166666666667]],
#   'iscrowd': 0},
#  {'id': 72,
#   'image_id': 62,
#   'category_id': 0,
#   'bbox': [284.0, 294.0, 146.0, 73.0],
#   'area': 10658.0,
#   'segmentation': [[0.44375,
#     0.6125,
#     0.671875,
#     0.6125,
#     0.671875,
#     0.7645833333333333,
#     0.44375,
#     0.7645833333333333]],
#   'iscrowd': 0},
#  {'id': 73,
#   'image_id': 63,
#   'category_id': 0,
#   'bbox': [115.0, 107.0, 419.0, 179.0],
#   'area': 75001.0,
#   'segmentation': [[0.1796875,
#     0.22291666666666668,
#     0.834375,
#     0.22291666666666668,
#     0.834375,
#     0.5958333333333333,
#     0.1796875,
#     0.5958333333333333]],
#   'iscrowd': 0},
#  {'id': 74,
#   'image_id': 64,
#   'category_id': 1,
#   'bbox': [151.0, 120.0, 342.0, 260.0],
#   'area': 88920.0,
#   'segmentation': [[0.2359375,
#     0.25,
#     0.7703125,
#     0.25,
#     0.7703125,
#     0.7916666666666666,
#     0.2359375,
#     0.7916666666666666]],
#   'iscrowd': 0},
#  {'id': 75,
#   'image_id': 65,
#   'category_id': 1,
#   'bbox': [242.0, 306.0, 320.0, 174.0],
#   'area': 55680.0,
#   'segmentation': [[0.378125,
#     0.6375,
#     0.878125,
#     0.6375,
#     0.878125,
#     1.0,
#     0.378125,
#     1.0]],
#   'iscrowd': 0},
#  {'id': 76,
#   'image_id': 66,
#   'category_id': 1,
#   'bbox': [80.0, 92.0, 100.0, 75.0],
#   'area': 7500.0,
#   'segmentation': [[0.125,
#     0.19166666666666668,
#     0.28125,
#     0.19166666666666668,
#     0.28125,
#     0.34791666666666665,
#     0.125,
#     0.34791666666666665]],
#   'iscrowd': 0},
#  {'id': 77,
#   'image_id': 67,
#   'category_id': 0,
#   'bbox': [268.0, 159.0, 166.0, 102.0],
#   'area': 16932.0,
#   'segmentation': [[0.41875,
#     0.33125,
#     0.678125,
#     0.33125,
#     0.678125,
#     0.54375,
#     0.41875,
#     0.54375]],
#   'iscrowd': 0},
#  {'id': 78,
#   'image_id': 68,
#   'category_id': 1,
#   'bbox': [73.0, 55.0, 408.0, 246.0],
#   'area': 100368.0,
#   'segmentation': [[0.1140625,
#     0.11458333333333333,
#     0.7515625,
#     0.11458333333333333,
#     0.7515625,
#     0.6270833333333333,
#     0.1140625,
#     0.6270833333333333]],
#   'iscrowd': 0},
#  {'id': 79,
#   'image_id': 69,
#   'category_id': 1,
#   'bbox': [273.0, 99.0, 285.0, 143.0],
#   'area': 40755.0,
#   'segmentation': [[0.4265625,
#     0.20625,
#     0.871875,
#     0.20625,
#     0.871875,
#     0.5041666666666667,
#     0.4265625,
#     0.5041666666666667]],
#   'iscrowd': 0},
#  {'id': 80,
#   'image_id': 70,
#   'category_id': 1,
#   'bbox': [335.0, 206.0, 80.0, 41.0],
#   'area': 3280.0,
#   'segmentation': [[0.5234375,
#     0.42916666666666664,
#     0.6484375,
#     0.42916666666666664,
#     0.6484375,
#     0.5145833333333333,
#     0.5234375,
#     0.5145833333333333]],
#   'iscrowd': 0},
#  {'id': 81,
#   'image_id': 71,
#   'category_id': 1,
#   'bbox': [347.0, 280.0, 150.0, 70.0],
#   'area': 10500.0,
#   'segmentation': [[0.5421875,
#     0.5833333333333334,
#     0.7765625,
#     0.5833333333333334,
#     0.7765625,
#     0.7291666666666666,
#     0.5421875,
#     0.7291666666666666]],
#   'iscrowd': 0},
#  {'id': 82,
#   'image_id': 72,
#   'category_id': 1,
#   'bbox': [46.0, 100.0, 558.0, 377.0],
#   'area': 210366.0,
#   'segmentation': [[0.071875,
#     0.20833333333333334,
#     0.94375,
#     0.20833333333333334,
#     0.94375,
#     0.99375,
#     0.071875,
#     0.99375]],
#   'iscrowd': 0},
#  {'id': 83,
#   'image_id': 73,
#   'category_id': 0,
#   'bbox': [153.0, 94.0, 338.0, 234.0],
#   'area': 79092.0,
#   'segmentation': [[0.2390625,
#     0.19583333333333333,
#     0.7671875,
#     0.19583333333333333,
#     0.7671875,
#     0.6833333333333333,
#     0.2390625,
#     0.6833333333333333]],
#   'iscrowd': 0},
#  {'id': 84,
#   'image_id': 74,
#   'category_id': 0,
#   'bbox': [72.0, 100.0, 482.0, 293.0],
#   'area': 141226.0,
#   'segmentation': [[0.1125,
#     0.20833333333333334,
#     0.865625,
#     0.20833333333333334,
#     0.865625,
#     0.81875,
#     0.1125,
#     0.81875]],
#   'iscrowd': 0},
#  {'id': 85,
#   'image_id': 75,
#   'category_id': 0,
#   'bbox': [73.0, 74.0, 541.0, 332.0],
#   'area': 179612.0,
#   'segmentation': [[0.1140625,
#     0.15416666666666667,
#     0.959375,
#     0.15416666666666667,
#     0.959375,
#     0.8458333333333333,
#     0.1140625,
#     0.8458333333333333]],
#   'iscrowd': 0},
#  {'id': 86,
#   'image_id': 76,
#   'category_id': 0,
#   'bbox': [95.0, 53.0, 448.0, 400.0],
#   'area': 179200.0,
#   'segmentation': [[0.1484375,
#     0.11041666666666666,
#     0.8484375,
#     0.11041666666666666,
#     0.8484375,
#     0.94375,
#     0.1484375,
#     0.94375]],
#   'iscrowd': 0},
#  {'id': 87,
#   'image_id': 77,
#   'category_id': 1,
#   'bbox': [202.0, 44.0, 271.0, 82.0],
#   'area': 22222.0,
#   'segmentation': [[0.315625,
#     0.09166666666666666,
#     0.7390625,
#     0.09166666666666666,
#     0.7390625,
#     0.2625,
#     0.315625,
#     0.2625]],
#   'iscrowd': 0},
#  {'id': 88,
#   'image_id': 78,
#   'category_id': 1,
#   'bbox': [16.0, 19.0, 500.0, 150.0],
#   'area': 75000.0,
#   'segmentation': [[0.025,
#     0.03958333333333333,
#     0.80625,
#     0.03958333333333333,
#     0.80625,
#     0.35208333333333336,
#     0.025,
#     0.35208333333333336]],
#   'iscrowd': 0},
#  {'id': 89,
#   'image_id': 79,
#   'category_id': 0,
#   'bbox': [177.0, 30.0, 274.0, 114.0],
#   'area': 31236.0,
#   'segmentation': [[0.2765625,
#     0.0625,
#     0.7046875,
#     0.0625,
#     0.7046875,
#     0.3,
#     0.2765625,
#     0.3]],
#   'iscrowd': 0},
#  {'id': 90,
#   'image_id': 80,
#   'category_id': 0,
#   'bbox': [250.0, 204.0, 142.0, 63.0],
#   'area': 8946.0,
#   'segmentation': [[0.390625,
#     0.425,
#     0.6125,
#     0.425,
#     0.6125,
#     0.55625,
#     0.390625,
#     0.55625]],
#   'iscrowd': 0},
#  {'id': 91,
#   'image_id': 81,
#   'category_id': 0,
#   'bbox': [252.0, 236.0, 107.0, 83.0],
#   'area': 8881.0,
#   'segmentation': [[0.39375,
#     0.49166666666666664,
#     0.5609375,
#     0.49166666666666664,
#     0.5609375,
#     0.6645833333333333,
#     0.39375,
#     0.6645833333333333]],
#   'iscrowd': 0},
#  {'id': 92,
#   'image_id': 82,
#   'category_id': 1,
#   'bbox': [147.0, 101.0, 400.0, 362.0],
#   'area': 144800.0,
#   'segmentation': [[0.2296875,
#     0.21041666666666667,
#     0.8546875,
#     0.21041666666666667,
#     0.8546875,
#     0.9645833333333333,
#     0.2296875,
#     0.9645833333333333]],
#   'iscrowd': 0},
#  {'id': 93,
#   'image_id': 83,
#   'category_id': 1,
#   'bbox': [92.0, 61.0, 407.0, 242.0],
#   'area': 98494.0,
#   'segmentation': [[0.14375,
#     0.12708333333333333,
#     0.7796875,
#     0.12708333333333333,
#     0.7796875,
#     0.63125,
#     0.14375,
#     0.63125]],
#   'iscrowd': 0},
#  {'id': 94,
#   'image_id': 84,
#   'category_id': 1,
#   'bbox': [308.0, 135.0, 123.0, 54.0],
#   'area': 6642.0,
#   'segmentation': [[0.48125,
#     0.28125,
#     0.6734375,
#     0.28125,
#     0.6734375,
#     0.39375,
#     0.48125,
#     0.39375]],
#   'iscrowd': 0},
#  {'id': 95,
#   'image_id': 85,
#   'category_id': 0,
#   'bbox': [200.0, 255.0, 102.0, 56.0],
#   'area': 5712.0,
#   'segmentation': [[0.3125,
#     0.53125,
#     0.471875,
#     0.53125,
#     0.471875,
#     0.6479166666666667,
#     0.3125,
#     0.6479166666666667]],
#   'iscrowd': 0},
#  {'id': 96,
#   'image_id': 86,
#   'category_id': 1,
#   'bbox': [192.0, 91.0, 233.0, 78.0],
#   'area': 18174.0,
#   'segmentation': [[0.3,
#     0.18958333333333333,
#     0.6640625,
#     0.18958333333333333,
#     0.6640625,
#     0.35208333333333336,
#     0.3,
#     0.35208333333333336]],
#   'iscrowd': 0},
#  {'id': 97,
#   'image_id': 87,
#   'category_id': 1,
#   'bbox': [334.0, 200.0, 297.0, 200.0],
#   'area': 59400.0,
#   'segmentation': [[0.521875,
#     0.4166666666666667,
#     0.9859375,
#     0.4166666666666667,
#     0.9859375,
#     0.8333333333333334,
#     0.521875,
#     0.8333333333333334]],
#   'iscrowd': 0},
#  {'id': 98,
#   'image_id': 87,
#   'category_id': 1,
#   'bbox': [79.0, 213.0, 264.0, 179.0],
#   'area': 47256.0,
#   'segmentation': [[0.1234375,
#     0.44375,
#     0.5359375,
#     0.44375,
#     0.5359375,
#     0.8166666666666667,
#     0.1234375,
#     0.8166666666666667]],
#   'iscrowd': 0},
#  {'id': 99,
#   'image_id': 87,
#   'category_id': 1,
#   'bbox': [180.0, 98.0, 275.0, 167.0],
#   'area': 45925.0,
#   'segmentation': [[0.28125,
#     0.20416666666666666,
#     0.7109375,
#     0.20416666666666666,
#     0.7109375,
#     0.5520833333333334,
#     0.28125,
#     0.5520833333333334]],
#   'iscrowd': 0},
#  {'id': 100,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [424.0, 184.0, 74.0, 111.0],
#   'area': 8214.0,
#   'segmentation': [[0.6625,
#     0.38333333333333336,
#     0.778125,
#     0.38333333333333336,
#     0.778125,
#     0.6145833333333334,
#     0.6625,
#     0.6145833333333334]],
#   'iscrowd': 0},
#  {'id': 101,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [35.0, 192.0, 207.0, 122.0],
#   'area': 25254.0,
#   'segmentation': [[0.0546875,
#     0.4,
#     0.378125,
#     0.4,
#     0.378125,
#     0.6541666666666667,
#     0.0546875,
#     0.6541666666666667]],
#   'iscrowd': 0},
#  {'id': 102,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [236.0, 190.0, 193.0, 121.0],
#   'area': 23353.0,
#   'segmentation': [[0.36875,
#     0.3958333333333333,
#     0.6703125,
#     0.3958333333333333,
#     0.6703125,
#     0.6479166666666667,
#     0.36875,
#     0.6479166666666667]],
#   'iscrowd': 0},
#  {'id': 103,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [178.0, 287.0, 210.0, 149.0],
#   'area': 31290.0,
#   'segmentation': [[0.278125,
#     0.5979166666666667,
#     0.60625,
#     0.5979166666666667,
#     0.60625,
#     0.9083333333333333,
#     0.278125,
#     0.9083333333333333]],
#   'iscrowd': 0},
#  {'id': 104,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [385.0, 292.0, 203.0, 147.0],
#   'area': 29841.0,
#   'segmentation': [[0.6015625,
#     0.6083333333333333,
#     0.91875,
#     0.6083333333333333,
#     0.91875,
#     0.9145833333333333,
#     0.6015625,
#     0.9145833333333333]],
#   'iscrowd': 0},
#  {'id': 105,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [14.0, 294.0, 212.0, 166.0],
#   'area': 35192.0,
#   'segmentation': [[0.021875,
#     0.6125,
#     0.353125,
#     0.6125,
#     0.353125,
#     0.9583333333333334,
#     0.021875,
#     0.9583333333333334]],
#   'iscrowd': 0},
#  {'id': 106,
#   'image_id': 88,
#   'category_id': 1,
#   'bbox': [156.0, 10.0, 269.0, 198.0],
#   'area': 53262.0,
#   'segmentation': [[0.24375,
#     0.020833333333333332,
#     0.6640625,
#     0.020833333333333332,
#     0.6640625,
#     0.43333333333333335,
#     0.24375,
#     0.43333333333333335]],
#   'iscrowd': 0},
#  {'id': 107,
#   'image_id': 89,
#   'category_id': 1,
#   'bbox': [69.0, 92.0, 104.0, 74.0],
#   'area': 7696.0,
#   'segmentation': [[0.1078125,
#     0.19166666666666668,
#     0.2703125,
#     0.19166666666666668,
#     0.2703125,
#     0.3458333333333333,
#     0.1078125,
#     0.3458333333333333]],
#   'iscrowd': 0},
#  {'id': 108,
#   'image_id': 90,
#   'category_id': 1,
#   'bbox': [0.0, 162.0, 640.0, 315.0],
#   'area': 201600.0,
#   'segmentation': [[0.0,
#     0.253125,
#     1.0,
#     0.253125,
#     1.0,
#     0.7453125,
#     0.0,
#     0.7453125]],
#   'iscrowd': 0},
#  {'id': 109,
#   'image_id': 91,
#   'category_id': 1,
#   'bbox': [129.0, 231.0, 225.0, 204.0],
#   'area': 45900.0,
#   'segmentation': [[0.2015625,
#     0.48125,
#     0.553125,
#     0.48125,
#     0.553125,
#     0.90625,
#     0.2015625,
#     0.90625]],
#   'iscrowd': 0},
#  {'id': 110,
#   'image_id': 92,
#   'category_id': 0,
#   'bbox': [117.0, 3.0, 447.0, 227.0],
#   'area': 101469.0,
#   'segmentation': [[0.1828125,
#     0.00625,
#     0.88125,
#     0.00625,
#     0.88125,
#     0.4791666666666667,
#     0.1828125,
#     0.4791666666666667]],
#   'iscrowd': 0},
#  {'id': 111,
#   'image_id': 93,
#   'category_id': 0,
#   'bbox': [0.0, 128.0, 496.0, 291.0],
#   'area': 144336.0,
#   'segmentation': [[0.0,
#     0.26666666666666666,
#     0.775,
#     0.26666666666666666,
#     0.775,
#     0.8729166666666667,
#     0.0,
#     0.8729166666666667]],
#   'iscrowd': 0},
#  {'id': 112,
#   'image_id': 94,
#   'category_id': 0,
#   'bbox': [250.0, 137.0, 390.0, 198.0],
#   'area': 77220.0,
#   'segmentation': [[0.390625,
#     0.28541666666666665,
#     1.0,
#     0.28541666666666665,
#     1.0,
#     0.6979166666666666,
#     0.390625,
#     0.6979166666666666]],
#   'iscrowd': 0},
#  {'id': 113,
#   'image_id': 95,
#   'category_id': 1,
#   'bbox': [233.0, 209.0, 174.0, 221.0],
#   'area': 38454.0,
#   'segmentation': [[0.3640625,
#     0.3265625,
#     0.6359375,
#     0.3265625,
#     0.6359375,
#     0.671875,
#     0.3640625,
#     0.671875]],
#   'iscrowd': 0},
#  {'id': 114,
#   'image_id': 96,
#   'category_id': 0,
#   'bbox': [97.0, 133.0, 519.0, 294.0],
#   'area': 152586.0,
#   'segmentation': [[0.1515625,
#     0.27708333333333335,
#     0.9625,
#     0.27708333333333335,
#     0.9625,
#     0.8895833333333333,
#     0.1515625,
#     0.8895833333333333]],
#   'iscrowd': 0},
#  {'id': 115,
#   'image_id': 97,
#   'category_id': 0,
#   'bbox': [0.0, 127.0, 637.0, 344.0],
#   'area': 219128.0,
#   'segmentation': [[0.0,
#     0.26458333333333334,
#     0.9953125,
#     0.26458333333333334,
#     0.9953125,
#     0.98125,
#     0.0,
#     0.98125]],
#   'iscrowd': 0},
#  {'id': 116,
#   'image_id': 98,
#   'category_id': 1,
#   'bbox': [60.0, 32.0, 517.0, 395.0],
#   'area': 204215.0,
#   'segmentation': [[0.09375,
#     0.06666666666666667,
#     0.9015625,
#     0.06666666666666667,
#     0.9015625,
#     0.8895833333333333,
#     0.09375,
#     0.8895833333333333]],
#   'iscrowd': 0},
#  {'id': 117,
#   'image_id': 99,
#   'category_id': 0,
#   'bbox': [9.0, 13.0, 629.0, 605.0],
#   'area': 380545.0,
#   'segmentation': [[0.0140625,
#     0.0203125,
#     0.996875,
#     0.0203125,
#     0.996875,
#     0.965625,
#     0.0140625,
#     0.965625]],
#   'iscrowd': 0},
#  {'id': 118,
#   'image_id': 100,
#   'category_id': 1,
#   'bbox': [122.0, 99.0, 187.0, 89.0],
#   'area': 16643.0,
#   'segmentation': [[0.190625,
#     0.20625,
#     0.4828125,
#     0.20625,
#     0.4828125,
#     0.39166666666666666,
#     0.190625,
#     0.39166666666666666]],
#   'iscrowd': 0},
#  {'id': 119,
#   'image_id': 101,
#   'category_id': 1,
#   'bbox': [147.0, 128.0, 327.0, 116.0],
#   'area': 37932.0,
#   'segmentation': [[0.2296875,
#     0.26666666666666666,
#     0.740625,
#     0.26666666666666666,
#     0.740625,
#     0.5083333333333333,
#     0.2296875,
#     0.5083333333333333]],
#   'iscrowd': 0},
#  {'id': 120,
#   'image_id': 102,
#   'category_id': 0,
#   'bbox': [80.0, 16.0, 484.0, 473.0],
#   'area': 228932.0,
#   'segmentation': [[0.125,
#     0.025,
#     0.88125,
#     0.025,
#     0.88125,
#     0.7640625,
#     0.125,
#     0.7640625]],
#   'iscrowd': 0},
#  {'id': 121,
#   'image_id': 103,
#   'category_id': 1,
#   'bbox': [132.0, 272.0, 162.0, 51.0],
#   'area': 8262.0,
#   'segmentation': [[0.20625,
#     0.5666666666666667,
#     0.459375,
#     0.5666666666666667,
#     0.459375,
#     0.6729166666666667,
#     0.20625,
#     0.6729166666666667]],
#   'iscrowd': 0},
#  {'id': 122,
#   'image_id': 104,
#   'category_id': 1,
#   'bbox': [230.0, 180.0, 111.0, 46.0],
#   'area': 5106.0,
#   'segmentation': [[0.359375,
#     0.375,
#     0.5328125,
#     0.375,
#     0.5328125,
#     0.4708333333333333,
#     0.359375,
#     0.4708333333333333]],
#   'iscrowd': 0},
#  {'id': 123,
#   'image_id': 105,
#   'category_id': 0,
#   'bbox': [180.0, 88.0, 399.0, 187.0],
#   'area': 74613.0,
#   'segmentation': [[0.28125,
#     0.18333333333333332,
#     0.9046875,
#     0.18333333333333332,
#     0.9046875,
#     0.5729166666666666,
#     0.28125,
#     0.5729166666666666]],
#   'iscrowd': 0},
#  {'id': 124,
#   'image_id': 106,
#   'category_id': 1,
#   'bbox': [164.0, 283.0, 136.0, 52.0],
#   'area': 7072.0,
#   'segmentation': [[0.25625,
#     0.5895833333333333,
#     0.46875,
#     0.5895833333333333,
#     0.46875,
#     0.6979166666666666,
#     0.25625,
#     0.6979166666666666]],
#   'iscrowd': 0},
#  {'id': 125,
#   'image_id': 107,
#   'category_id': 1,
#   'bbox': [314.0, 151.0, 111.0, 52.0],
#   'area': 5772.0,
#   'segmentation': [[0.490625,
#     0.3145833333333333,
#     0.6640625,
#     0.3145833333333333,
#     0.6640625,
#     0.42291666666666666,
#     0.490625,
#     0.42291666666666666]],
#   'iscrowd': 0},
#  {'id': 126,
#   'image_id': 108,
#   'category_id': 1,
#   'bbox': [175.0, 296.0, 128.0, 48.0],
#   'area': 6144.0,
#   'segmentation': [[0.2734375,
#     0.6166666666666667,
#     0.4734375,
#     0.6166666666666667,
#     0.4734375,
#     0.7166666666666667,
#     0.2734375,
#     0.7166666666666667]],
#   'iscrowd': 0},
#  {'id': 127,
#   'image_id': 109,
#   'category_id': 0,
#   'bbox': [264.0, 426.0, 141.0, 54.0],
#   'area': 7614.0,
#   'segmentation': [[0.4125,
#     0.8875,
#     0.6328125,
#     0.8875,
#     0.6328125,
#     1.0,
#     0.4125,
#     1.0]],
#   'iscrowd': 0},
#  {'id': 128,
#   'image_id': 110,
#   'category_id': 1,
#   'bbox': [80.0, 5.0, 487.0, 474.0],
#   'area': 230838.0,
#   'segmentation': [[0.125,
#     0.010416666666666666,
#     0.8859375,
#     0.010416666666666666,
#     0.8859375,
#     0.9979166666666667,
#     0.125,
#     0.9979166666666667]],
#   'iscrowd': 0},
#  {'id': 129,
#   'image_id': 111,
#   'category_id': 0,
#   'bbox': [152.0, 45.0, 295.0, 368.0],
#   'area': 108560.0,
#   'segmentation': [[0.2375,
#     0.09375,
#     0.6984375,
#     0.09375,
#     0.6984375,
#     0.8604166666666667,
#     0.2375,
#     0.8604166666666667]],
#   'iscrowd': 0},
#  {'id': 130,
#   'image_id': 112,
#   'category_id': 1,
#   'bbox': [208.0, 220.0, 194.0, 61.0],
#   'area': 11834.0,
#   'segmentation': [[0.325,
#     0.4583333333333333,
#     0.628125,
#     0.4583333333333333,
#     0.628125,
#     0.5854166666666667,
#     0.325,
#     0.5854166666666667]],
#   'iscrowd': 0},
#  {'id': 131,
#   'image_id': 113,
#   'category_id': 1,
#   'bbox': [104.0, 189.0, 194.0, 89.0],
#   'area': 17266.0,
#   'segmentation': [[0.1625,
#     0.39375,
#     0.465625,
#     0.39375,
#     0.465625,
#     0.5791666666666667,
#     0.1625,
#     0.5791666666666667]],
#   'iscrowd': 0},
#  {'id': 132,
#   'image_id': 114,
#   'category_id': 1,
#   'bbox': [190.0, 283.0, 120.0, 45.0],
#   'area': 5400.0,
#   'segmentation': [[0.296875,
#     0.5895833333333333,
#     0.484375,
#     0.5895833333333333,
#     0.484375,
#     0.6833333333333333,
#     0.296875,
#     0.6833333333333333]],
#   'iscrowd': 0},
#  {'id': 133,
#   'image_id': 115,
#   'category_id': 0,
#   'bbox': [140.0, 107.0, 392.0, 315.0],
#   'area': 123480.0,
#   'segmentation': [[0.21875,
#     0.22291666666666668,
#     0.83125,
#     0.22291666666666668,
#     0.83125,
#     0.8791666666666667,
#     0.21875,
#     0.8791666666666667]],
#   'iscrowd': 0},
#  {'id': 134,
#   'image_id': 115,
#   'category_id': 1,
#   'bbox': [104.0, 58.0, 348.0, 234.0],
#   'area': 81432.0,
#   'segmentation': [[0.1625,
#     0.12083333333333333,
#     0.70625,
#     0.12083333333333333,
#     0.70625,
#     0.6083333333333333,
#     0.1625,
#     0.6083333333333333]],
#   'iscrowd': 0},
#  {'id': 135,
#   'image_id': 116,
#   'category_id': 1,
#   'bbox': [353.0, 89.0, 205.0, 64.0],
#   'area': 13120.0,
#   'segmentation': [[0.5515625,
#     0.18541666666666667,
#     0.871875,
#     0.18541666666666667,
#     0.871875,
#     0.31875,
#     0.5515625,
#     0.31875]],
#   'iscrowd': 0},
#  {'id': 136,
#   'image_id': 117,
#   'category_id': 1,
#   'bbox': [160.0, 87.0, 271.0, 134.0],
#   'area': 36314.0,
#   'segmentation': [[0.25,
#     0.18125,
#     0.6734375,
#     0.18125,
#     0.6734375,
#     0.46041666666666664,
#     0.25,
#     0.46041666666666664]],
#   'iscrowd': 0},
#  {'id': 137,
#   'image_id': 117,
#   'category_id': 1,
#   'bbox': [126.0, 166.0, 335.0, 159.0],
#   'area': 53265.0,
#   'segmentation': [[0.196875,
#     0.3458333333333333,
#     0.7203125,
#     0.3458333333333333,
#     0.7203125,
#     0.6770833333333334,
#     0.196875,
#     0.6770833333333334]],
#   'iscrowd': 0},
#  {'id': 138,
#   'image_id': 117,
#   'category_id': 1,
#   'bbox': [61.0, 215.0, 483.0, 212.0],
#   'area': 102396.0,
#   'segmentation': [[0.0953125,
#     0.4479166666666667,
#     0.85,
#     0.4479166666666667,
#     0.85,
#     0.8895833333333333,
#     0.0953125,
#     0.8895833333333333]],
#   'iscrowd': 0},
#  {'id': 139,
#   'image_id': 118,
#   'category_id': 1,
#   'bbox': [315.0, 91.0, 193.0, 75.0],
#   'area': 14475.0,
#   'segmentation': [[0.4921875,
#     0.18958333333333333,
#     0.79375,
#     0.18958333333333333,
#     0.79375,
#     0.3458333333333333,
#     0.4921875,
#     0.3458333333333333]],
#   'iscrowd': 0},
#  {'id': 140,
#   'image_id': 119,
#   'category_id': 0,
#   'bbox': [184.0, 97.0, 406.0, 206.0],
#   'area': 83636.0,
#   'segmentation': [[0.2875,
#     0.20208333333333334,
#     0.921875,
#     0.20208333333333334,
#     0.921875,
#     0.63125,
#     0.2875,
#     0.63125]],
#   'iscrowd': 0},
#  {'id': 141,
#   'image_id': 120,
#   'category_id': 0,
#   'bbox': [234.0, 48.0, 144.0, 372.0],
#   'area': 53568.0,
#   'segmentation': [[0.365625,
#     0.1,
#     0.590625,
#     0.1,
#     0.590625,
#     0.875,
#     0.365625,
#     0.875]],
#   'iscrowd': 0},
#  {'id': 142,
#   'image_id': 121,
#   'category_id': 0,
#   'bbox': [246.0, 232.0, 242.0, 177.0],
#   'area': 42834.0,
#   'segmentation': [[0.384375,
#     0.48333333333333334,
#     0.7625,
#     0.48333333333333334,
#     0.7625,
#     0.8520833333333333,
#     0.384375,
#     0.8520833333333333]],
#   'iscrowd': 0},
#  {'id': 143,
#   'image_id': 122,
#   'category_id': 0,
#   'bbox': [80.0, 37.0, 424.0, 423.0],
#   'area': 179352.0,
#   'segmentation': [[0.125,
#     0.07708333333333334,
#     0.7875,
#     0.07708333333333334,
#     0.7875,
#     0.9583333333333334,
#     0.125,
#     0.9583333333333334]],
#   'iscrowd': 0},
#  {'id': 144,
#   'image_id': 123,
#   'category_id': 0,
#   'bbox': [269.0, 204.0, 104.0, 48.0],
#   'area': 4992.0,
#   'segmentation': [[0.4203125,
#     0.425,
#     0.5828125,
#     0.425,
#     0.5828125,
#     0.525,
#     0.4203125,
#     0.525]],
#   'iscrowd': 0},
#  {'id': 145,
#   'image_id': 125,
#   'category_id': 1,
#   'bbox': [169.0, 80.0, 301.0, 308.0],
#   'area': 92708.0,
#   'segmentation': [[0.2640625,
#     0.16666666666666666,
#     0.734375,
#     0.16666666666666666,
#     0.734375,
#     0.8083333333333333,
#     0.2640625,
#     0.8083333333333333]],
#   'iscrowd': 0},
#  {'id': 146,
#   'image_id': 126,
#   'category_id': 1,
#   'bbox': [97.0, 191.0, 196.0, 92.0],
#   'area': 18032.0,
#   'segmentation': [[0.1515625,
#     0.39791666666666664,
#     0.4578125,
#     0.39791666666666664,
#     0.4578125,
#     0.5895833333333333,
#     0.1515625,
#     0.5895833333333333]],
#   'iscrowd': 0},
#  {'id': 147,
#   'image_id': 127,
#   'category_id': 0,
#   'bbox': [170.0, 122.0, 284.0, 164.0],
#   'area': 46576.0,
#   'segmentation': [[0.265625,
#     0.25416666666666665,
#     0.709375,
#     0.25416666666666665,
#     0.709375,
#     0.5958333333333333,
#     0.265625,
#     0.5958333333333333]],
#   'iscrowd': 0},
#  {'id': 148,
#   'image_id': 128,
#   'category_id': 0,
#   'bbox': [63.0, 60.0, 305.0, 136.0],
#   'area': 41480.0,
#   'segmentation': [[0.0984375,
#     0.125,
#     0.575,
#     0.125,
#     0.575,
#     0.4083333333333333,
#     0.0984375,
#     0.4083333333333333]],
#   'iscrowd': 0},
#  {'id': 149,
#   'image_id': 129,
#   'category_id': 1,
#   'bbox': [302.0, 165.0, 105.0, 47.0],
#   'area': 4935.0,
#   'segmentation': [[0.471875,
#     0.34375,
#     0.6359375,
#     0.34375,
#     0.6359375,
#     0.44166666666666665,
#     0.471875,
#     0.44166666666666665]],
#   'iscrowd': 0},
#  {'id': 150,
#   'image_id': 130,
#   'category_id': 0,
#   'bbox': [0.0, 119.0, 607.0, 299.0],
#   'area': 181493.0,
#   'segmentation': [[0.0,
#     0.24791666666666667,
#     0.9484375,
#     0.24791666666666667,
#     0.9484375,
#     0.8708333333333333,
#     0.0,
#     0.8708333333333333]],
#   'iscrowd': 0},
#  {'id': 151,
#   'image_id': 131,
#   'category_id': 1,
#   'bbox': [80.0, 26.0, 373.0, 215.0],
#   'area': 80195.0,
#   'segmentation': [[0.125,
#     0.05416666666666667,
#     0.7078125,
#     0.05416666666666667,
#     0.7078125,
#     0.5020833333333333,
#     0.125,
#     0.5020833333333333]],
#   'iscrowd': 0},
#  {'id': 152,
#   'image_id': 132,
#   'category_id': 1,
#   'bbox': [23.0, 40.0, 571.0, 560.0],
#   'area': 319760.0,
#   'segmentation': [[0.0359375,
#     0.0625,
#     0.928125,
#     0.0625,
#     0.928125,
#     0.9375,
#     0.0359375,
#     0.9375]],
#   'iscrowd': 0},
#  {'id': 153,
#   'image_id': 133,
#   'category_id': 1,
#   'bbox': [148.0, 88.0, 324.0, 303.0],
#   'area': 98172.0,
#   'segmentation': [[0.23125,
#     0.18333333333333332,
#     0.7375,
#     0.18333333333333332,
#     0.7375,
#     0.8145833333333333,
#     0.23125,
#     0.8145833333333333]],
#   'iscrowd': 0},
#  {'id': 154,
#   'image_id': 134,
#   'category_id': 1,
#   'bbox': [276.0, 221.0, 208.0, 79.0],
#   'area': 16432.0,
#   'segmentation': [[0.43125,
#     0.46041666666666664,
#     0.75625,
#     0.46041666666666664,
#     0.75625,
#     0.625,
#     0.43125,
#     0.625]],
#   'iscrowd': 0},
#  {'id': 155,
#   'image_id': 135,
#   'category_id': 0,
#   'bbox': [157.0, 90.0, 336.0, 224.0],
#   'area': 75264.0,
#   'segmentation': [[0.2453125,
#     0.1875,
#     0.7703125,
#     0.1875,
#     0.7703125,
#     0.6541666666666667,
#     0.2453125,
#     0.6541666666666667]],
#   'iscrowd': 0},
#  {'id': 156,
#   'image_id': 136,
#   'category_id': 1,
#   'bbox': [148.0, 190.0, 173.0, 57.0],
#   'area': 9861.0,
#   'segmentation': [[0.23125,
#     0.3958333333333333,
#     0.5015625,
#     0.3958333333333333,
#     0.5015625,
#     0.5145833333333333,
#     0.23125,
#     0.5145833333333333]],
#   'iscrowd': 0},
#  {'id': 157,
#   'image_id': 137,
#   'category_id': 1,
#   'bbox': [423.0, 55.0, 137.0, 64.0],
#   'area': 8768.0,
#   'segmentation': [[0.6609375,
#     0.11458333333333333,
#     0.875,
#     0.11458333333333333,
#     0.875,
#     0.24791666666666667,
#     0.6609375,
#     0.24791666666666667]],
#   'iscrowd': 0},
#  {'id': 158,
#   'image_id': 138,
#   'category_id': 1,
#   'bbox': [456.0, 51.0, 182.0, 62.0],
#   'area': 11284.0,
#   'segmentation': [[0.7125,
#     0.10625,
#     0.996875,
#     0.10625,
#     0.996875,
#     0.23541666666666666,
#     0.7125,
#     0.23541666666666666]],
#   'iscrowd': 0},
#  {'id': 159,
#   'image_id': 140,
#   'category_id': 1,
#   'bbox': [271.0, 222.0, 159.0, 67.0],
#   'area': 10653.0,
#   'segmentation': [[0.4234375,
#     0.4625,
#     0.671875,
#     0.4625,
#     0.671875,
#     0.6020833333333333,
#     0.4234375,
#     0.6020833333333333]],
#   'iscrowd': 0},
#  {'id': 160,
#   'image_id': 141,
#   'category_id': 1,
#   'bbox': [105.0, 47.0, 438.0, 369.0],
#   'area': 161622.0,
#   'segmentation': [[0.1640625,
#     0.09791666666666667,
#     0.8484375,
#     0.09791666666666667,
#     0.8484375,
#     0.8666666666666667,
#     0.1640625,
#     0.8666666666666667]],
#   'iscrowd': 0},
#  {'id': 161,
#   'image_id': 142,
#   'category_id': 1,
#   'bbox': [209.0, 177.0, 142.0, 45.0],
#   'area': 6390.0,
#   'segmentation': [[0.3265625,
#     0.36875,
#     0.5484375,
#     0.36875,
#     0.5484375,
#     0.4625,
#     0.3265625,
#     0.4625]],
#   'iscrowd': 0},
#  {'id': 162,
#   'image_id': 143,
#   'category_id': 1,
#   'bbox': [139.0, 68.0, 428.0, 518.0],
#   'area': 221704.0,
#   'segmentation': [[0.2171875,
#     0.10625,
#     0.8859375,
#     0.10625,
#     0.8859375,
#     0.915625,
#     0.2171875,
#     0.915625]],
#   'iscrowd': 0},
#  {'id': 163,
#   'image_id': 144,
#   'category_id': 1,
#   'bbox': [451.0, 411.0, 133.0, 98.0],
#   'area': 13034.0,
#   'segmentation': [[0.4404296875,
#     0.802734375,
#     0.5703125,
#     0.802734375,
#     0.5703125,
#     0.994140625,
#     0.4404296875,
#     0.994140625]],
#   'iscrowd': 0},
#  {'id': 164,
#   'image_id': 145,
#   'category_id': 1,
#   'bbox': [295.0, 162.0, 130.0, 45.0],
#   'area': 5850.0,
#   'segmentation': [[0.4609375,
#     0.3375,
#     0.6640625,
#     0.3375,
#     0.6640625,
#     0.43125,
#     0.4609375,
#     0.43125]],
#   'iscrowd': 0},
#  {'id': 165,
#   'image_id': 146,
#   'category_id': 0,
#   'bbox': [264.0, 17.0, 161.0, 281.0],
#   'area': 45241.0,
#   'segmentation': [[0.4125,
#     0.035416666666666666,
#     0.6640625,
#     0.035416666666666666,
#     0.6640625,
#     0.6208333333333333,
#     0.4125,
#     0.6208333333333333]],
#   'iscrowd': 0},
#  {'id': 166,
#   'image_id': 147,
#   'category_id': 0,
#   'bbox': [33.0, 23.0, 580.0, 603.0],
#   'area': 349740.0,
#   'segmentation': [[0.0515625,
#     0.0359375,
#     0.9578125,
#     0.0359375,
#     0.9578125,
#     0.978125,
#     0.0515625,
#     0.978125]],
#   'iscrowd': 0},
#  {'id': 167,
#   'image_id': 148,
#   'category_id': 1,
#   'bbox': [311.0, 76.0, 147.0, 59.0],
#   'area': 8673.0,
#   'segmentation': [[0.4859375,
#     0.15833333333333333,
#     0.715625,
#     0.15833333333333333,
#     0.715625,
#     0.28125,
#     0.4859375,
#     0.28125]],
#   'iscrowd': 0},
#  {'id': 168,
#   'image_id': 149,
#   'category_id': 1,
#   'bbox': [98.0, 30.0, 428.0, 419.0],
#   'area': 179332.0,
#   'segmentation': [[0.153125,
#     0.0625,
#     0.821875,
#     0.0625,
#     0.821875,
#     0.9354166666666667,
#     0.153125,
#     0.9354166666666667]],
#   'iscrowd': 0},
#  {'id': 169,
#   'image_id': 150,
#   'category_id': 1,
#   'bbox': [287.0, 111.0, 160.0, 136.0],
#   'area': 21760.0,
#   'segmentation': [[0.2802734375,
#     0.216796875,
#     0.4365234375,
#     0.216796875,
#     0.4365234375,
#     0.482421875,
#     0.2802734375,
#     0.482421875]],
#   'iscrowd': 0},
#  {'id': 170,
#   'image_id': 151,
#   'category_id': 0,
#   'bbox': [200.0, 186.0, 199.0, 136.0],
#   'area': 27064.0,
#   'segmentation': [[0.3125,
#     0.3875,
#     0.6234375,
#     0.3875,
#     0.6234375,
#     0.6708333333333333,
#     0.3125,
#     0.6708333333333333]],
#   'iscrowd': 0},
#  {'id': 171,
#   'image_id': 152,
#   'category_id': 1,
#   'bbox': [64.0, 62.0, 409.0, 240.0],
#   'area': 98160.0,
#   'segmentation': [[0.1,
#     0.12916666666666668,
#     0.7390625,
#     0.12916666666666668,
#     0.7390625,
#     0.6291666666666667,
#     0.1,
#     0.6291666666666667]],
#   'iscrowd': 0},
#  {'id': 172,
#   'image_id': 153,
#   'category_id': 0,
#   'bbox': [324.0, 448.0, 132.0, 29.0],
#   'area': 3828.0,
#   'segmentation': [[0.50625,
# ...
#     0.590625,
#     0.33541666666666664,
#     0.590625,
#     0.6979166666666666,
#     0.1296875,
#     0.6979166666666666]],
#   'iscrowd': 0},
#  {'id': 944,
#   'image_id': 757,
#   'category_id': 0,
#   'bbox': [123.0, 154.0, 355.0, 218.0],
#   'area': 77390.0,
#   'segmentation': [[0.1921875,
#     0.32083333333333336,
#     0.746875,
#     0.32083333333333336,
#     0.746875,
#     0.775,
#     0.1921875,
#     0.775]],
#   'iscrowd': 0},
#  {'id': 945,
#   'image_id': 758,
#   'category_id': 0,
#   'bbox': [0.0, 47.0, 250.0, 117.0],
#   'area': 29250.0,
#   'segmentation': [[0.0,
#     0.09791666666666667,
#     0.390625,
#     0.09791666666666667,
#     0.390625,
#     0.3416666666666667,
#     0.0,
#     0.3416666666666667]],
#   'iscrowd': 0},
#  {'id': 946,
#   'image_id': 759,
#   'category_id': 1,
#   'bbox': [161.0, 90.0, 367.0, 183.0],
#   'area': 67161.0,
#   'segmentation': [[0.2515625,
#     0.1875,
#     0.825,
#     0.1875,
#     0.825,
#     0.56875,
#     0.2515625,
#     0.56875]],
#   'iscrowd': 0},
#  {'id': 947,
#   'image_id': 760,
#   'category_id': 0,
#   'bbox': [118.0, 32.0, 381.0, 210.0],
#   'area': 80010.0,
#   'segmentation': [[0.184375,
#     0.06666666666666667,
#     0.7796875,
#     0.06666666666666667,
#     0.7796875,
#     0.5041666666666667,
#     0.184375,
#     0.5041666666666667]],
#   'iscrowd': 0},
#  {'id': 948,
#   'image_id': 761,
#   'category_id': 1,
#   'bbox': [39.0, 52.0, 566.0, 543.0],
#   'area': 307338.0,
#   'segmentation': [[0.0609375,
#     0.08125,
#     0.9453125,
#     0.08125,
#     0.9453125,
#     0.9296875,
#     0.0609375,
#     0.9296875]],
#   'iscrowd': 0},
#  {'id': 949,
#   'image_id': 762,
#   'category_id': 0,
#   'bbox': [208.0, 77.0, 281.0, 390.0],
#   'area': 109590.0,
#   'segmentation': [[0.325,
#     0.16041666666666668,
#     0.7640625,
#     0.16041666666666668,
#     0.7640625,
#     0.9729166666666667,
#     0.325,
#     0.9729166666666667]],
#   'iscrowd': 0},
#  {'id': 950,
#   'image_id': 763,
#   'category_id': 0,
#   'bbox': [122.0, 77.0, 342.0, 160.0],
#   'area': 54720.0,
#   'segmentation': [[0.190625,
#     0.16041666666666668,
#     0.725,
#     0.16041666666666668,
#     0.725,
#     0.49375,
#     0.190625,
#     0.49375]],
#   'iscrowd': 0},
#  {'id': 951,
#   'image_id': 764,
#   'category_id': 1,
#   'bbox': [114.0, 194.0, 214.0, 58.0],
#   'area': 12412.0,
#   'segmentation': [[0.178125,
#     0.4041666666666667,
#     0.5125,
#     0.4041666666666667,
#     0.5125,
#     0.525,
#     0.178125,
#     0.525]],
#   'iscrowd': 0},
#  {'id': 952,
#   'image_id': 765,
#   'category_id': 0,
#   'bbox': [307.0, 131.0, 70.0, 42.0],
#   'area': 2940.0,
#   'segmentation': [[0.4796875,
#     0.27291666666666664,
#     0.5890625,
#     0.27291666666666664,
#     0.5890625,
#     0.36041666666666666,
#     0.4796875,
#     0.36041666666666666]],
#   'iscrowd': 0},
#  {'id': 953,
#   'image_id': 765,
#   'category_id': 1,
#   'bbox': [16.0, 105.0, 43.0, 19.0],
#   'area': 817.0,
#   'segmentation': [[0.025,
#     0.21875,
#     0.0921875,
#     0.21875,
#     0.0921875,
#     0.25833333333333336,
#     0.025,
#     0.25833333333333336]],
#   'iscrowd': 0},
#  {'id': 954,
#   'image_id': 766,
#   'category_id': 1,
#   'bbox': [80.0, 122.0, 480.0, 244.0],
#   'area': 117120.0,
#   'segmentation': [[0.125,
#     0.25416666666666665,
#     0.875,
#     0.25416666666666665,
#     0.875,
#     0.7625,
#     0.125,
#     0.7625]],
#   'iscrowd': 0},
#  {'id': 955,
#   'image_id': 767,
#   'category_id': 1,
#   'bbox': [311.0, 125.0, 240.0, 69.0],
#   'area': 16560.0,
#   'segmentation': [[0.4859375,
#     0.2604166666666667,
#     0.8609375,
#     0.2604166666666667,
#     0.8609375,
#     0.4041666666666667,
#     0.4859375,
#     0.4041666666666667]],
#   'iscrowd': 0},
#  {'id': 956,
#   'image_id': 768,
#   'category_id': 1,
#   'bbox': [281.0, 198.0, 127.0, 46.0],
#   'area': 5842.0,
#   'segmentation': [[0.4390625,
#     0.4125,
#     0.6375,
#     0.4125,
#     0.6375,
#     0.5083333333333333,
#     0.4390625,
#     0.5083333333333333]],
#   'iscrowd': 0},
#  {'id': 957,
#   'image_id': 769,
#   'category_id': 1,
#   'bbox': [443.0, 42.0, 115.0, 100.0],
#   'area': 11500.0,
#   'segmentation': [[0.6921875,
#     0.0875,
#     0.871875,
#     0.0875,
#     0.871875,
#     0.29583333333333334,
#     0.6921875,
#     0.29583333333333334]],
#   'iscrowd': 0},
#  {'id': 958,
#   'image_id': 769,
#   'category_id': 1,
#   'bbox': [122.0, 64.0, 110.0, 89.0],
#   'area': 9790.0,
#   'segmentation': [[0.190625,
#     0.13333333333333333,
#     0.3625,
#     0.13333333333333333,
#     0.3625,
#     0.31875,
#     0.190625,
#     0.31875]],
#   'iscrowd': 0},
#  {'id': 959,
#   'image_id': 769,
#   'category_id': 1,
#   'bbox': [483.0, 242.0, 91.0, 159.0],
#   'area': 14469.0,
#   'segmentation': [[0.7546875,
#     0.5041666666666667,
#     0.896875,
#     0.5041666666666667,
#     0.896875,
#     0.8354166666666667,
#     0.7546875,
#     0.8354166666666667]],
#   'iscrowd': 0},
#  {'id': 960,
#   'image_id': 769,
#   'category_id': 1,
#   'bbox': [167.0, 278.0, 157.0, 113.0],
#   'area': 17741.0,
#   'segmentation': [[0.2609375,
#     0.5791666666666667,
#     0.50625,
#     0.5791666666666667,
#     0.50625,
#     0.8145833333333333,
#     0.2609375,
#     0.8145833333333333]],
#   'iscrowd': 0},
#  {'id': 961,
#   'image_id': 770,
#   'category_id': 0,
#   'bbox': [294.0, 182.0, 152.0, 71.0],
#   'area': 10792.0,
#   'segmentation': [[0.459375,
#     0.37916666666666665,
#     0.696875,
#     0.37916666666666665,
#     0.696875,
#     0.5270833333333333,
#     0.459375,
#     0.5270833333333333]],
#   'iscrowd': 0},
#  {'id': 962,
#   'image_id': 772,
#   'category_id': 0,
#   'bbox': [26.0, 9.0, 602.0, 460.0],
#   'area': 276920.0,
#   'segmentation': [[0.040625,
#     0.01875,
#     0.98125,
#     0.01875,
#     0.98125,
#     0.9770833333333333,
#     0.040625,
#     0.9770833333333333]],
#   'iscrowd': 0},
#  {'id': 963,
#   'image_id': 773,
#   'category_id': 1,
#   'bbox': [98.0, 31.0, 471.0, 408.0],
#   'area': 192168.0,
#   'segmentation': [[0.153125,
#     0.06458333333333334,
#     0.8890625,
#     0.06458333333333334,
#     0.8890625,
#     0.9145833333333333,
#     0.153125,
#     0.9145833333333333]],
#   'iscrowd': 0},
#  {'id': 964,
#   'image_id': 774,
#   'category_id': 0,
#   'bbox': [53.0, 41.0, 532.0, 551.0],
#   'area': 293132.0,
#   'segmentation': [[0.0828125,
#     0.0640625,
#     0.9140625,
#     0.0640625,
#     0.9140625,
#     0.925,
#     0.0828125,
#     0.925]],
#   'iscrowd': 0},
#  {'id': 965,
#   'image_id': 775,
#   'category_id': 0,
#   'bbox': [204.0, 129.0, 364.0, 155.0],
#   'area': 56420.0,
#   'segmentation': [[0.31875,
#     0.26875,
#     0.8875,
#     0.26875,
#     0.8875,
#     0.5916666666666667,
#     0.31875,
#     0.5916666666666667]],
#   'iscrowd': 0},
#  {'id': 966,
#   'image_id': 776,
#   'category_id': 1,
#   'bbox': [325.0, 161.0, 143.0, 71.0],
#   'area': 10153.0,
#   'segmentation': [[0.5078125,
#     0.33541666666666664,
#     0.73125,
#     0.33541666666666664,
#     0.73125,
#     0.48333333333333334,
#     0.5078125,
#     0.48333333333333334]],
#   'iscrowd': 0},
#  {'id': 967,
#   'image_id': 777,
#   'category_id': 1,
#   'bbox': [248.0, 146.0, 178.0, 93.0],
#   'area': 16554.0,
#   'segmentation': [[0.3875,
#     0.30416666666666664,
#     0.665625,
#     0.30416666666666664,
#     0.665625,
#     0.4979166666666667,
#     0.3875,
#     0.4979166666666667]],
#   'iscrowd': 0},
#  {'id': 968,
#   'image_id': 778,
#   'category_id': 0,
#   'bbox': [256.0, 122.0, 382.0, 268.0],
#   'area': 102376.0,
#   'segmentation': [[0.4,
#     0.25416666666666665,
#     0.996875,
#     0.25416666666666665,
#     0.996875,
#     0.8125,
#     0.4,
#     0.8125]],
#   'iscrowd': 0},
#  {'id': 969,
#   'image_id': 779,
#   'category_id': 0,
#   'bbox': [53.0, 76.0, 495.0, 367.0],
#   'area': 181665.0,
#   'segmentation': [[0.0828125,
#     0.15833333333333333,
#     0.85625,
#     0.15833333333333333,
#     0.85625,
#     0.9229166666666667,
#     0.0828125,
#     0.9229166666666667]],
#   'iscrowd': 0},
#  {'id': 970,
#   'image_id': 780,
#   'category_id': 1,
#   'bbox': [134.0, 99.0, 308.0, 322.0],
#   'area': 99176.0,
#   'segmentation': [[0.209375,
#     0.20625,
#     0.690625,
#     0.20625,
#     0.690625,
#     0.8770833333333333,
#     0.209375,
#     0.8770833333333333]],
#   'iscrowd': 0},
#  {'id': 971,
#   'image_id': 781,
#   'category_id': 1,
#   'bbox': [333.0, 137.0, 221.0, 78.0],
#   'area': 17238.0,
#   'segmentation': [[0.5203125,
#     0.28541666666666665,
#     0.865625,
#     0.28541666666666665,
#     0.865625,
#     0.4479166666666667,
#     0.5203125,
#     0.4479166666666667]],
#   'iscrowd': 0},
#  {'id': 972,
#   'image_id': 782,
#   'category_id': 1,
#   'bbox': [0.0, 88.0, 227.0, 74.0],
#   'area': 16798.0,
#   'segmentation': [[0.0,
#     0.18333333333333332,
#     0.3546875,
#     0.18333333333333332,
#     0.3546875,
#     0.3375,
#     0.0,
#     0.3375]],
#   'iscrowd': 0},
#  {'id': 973,
#   'image_id': 783,
#   'category_id': 1,
#   'bbox': [128.0, 100.0, 408.0, 341.0],
#   'area': 139128.0,
#   'segmentation': [[0.2,
#     0.20833333333333334,
#     0.8375,
#     0.20833333333333334,
#     0.8375,
#     0.91875,
#     0.2,
#     0.91875]],
#   'iscrowd': 0},
#  {'id': 974,
#   'image_id': 784,
#   'category_id': 1,
#   'bbox': [23.0, 102.0, 184.0, 61.0],
#   'area': 11224.0,
#   'segmentation': [[0.0359375,
#     0.2125,
#     0.3234375,
#     0.2125,
#     0.3234375,
#     0.33958333333333335,
#     0.0359375,
#     0.33958333333333335]],
#   'iscrowd': 0},
#  {'id': 975,
#   'image_id': 785,
#   'category_id': 0,
#   'bbox': [152.0, 227.0, 100.0, 43.0],
#   'area': 4300.0,
#   'segmentation': [[0.2375,
#     0.47291666666666665,
#     0.39375,
#     0.47291666666666665,
#     0.39375,
#     0.5625,
#     0.2375,
#     0.5625]],
#   'iscrowd': 0},
#  {'id': 976,
#   'image_id': 786,
#   'category_id': 0,
#   'bbox': [93.0, 8.0, 201.0, 442.0],
#   'area': 88842.0,
#   'segmentation': [[0.1453125,
#     0.016666666666666666,
#     0.459375,
#     0.016666666666666666,
#     0.459375,
#     0.9375,
#     0.1453125,
#     0.9375]],
#   'iscrowd': 0},
#  {'id': 977,
#   'image_id': 786,
#   'category_id': 1,
#   'bbox': [257.0, 120.0, 143.0, 148.0],
#   'area': 21164.0,
#   'segmentation': [[0.4015625,
#     0.25,
#     0.625,
#     0.25,
#     0.625,
#     0.5583333333333333,
#     0.4015625,
#     0.5583333333333333]],
#   'iscrowd': 0},
#  {'id': 978,
#   'image_id': 786,
#   'category_id': 1,
#   'bbox': [263.0, 249.0, 141.0, 193.0],
#   'area': 27213.0,
#   'segmentation': [[0.4109375,
#     0.51875,
#     0.63125,
#     0.51875,
#     0.63125,
#     0.9208333333333333,
#     0.4109375,
#     0.9208333333333333]],
#   'iscrowd': 0},
#  {'id': 979,
#   'image_id': 786,
#   'category_id': 1,
#   'bbox': [403.0, 184.0, 105.0, 142.0],
#   'area': 14910.0,
#   'segmentation': [[0.6296875,
#     0.38333333333333336,
#     0.79375,
#     0.38333333333333336,
#     0.79375,
#     0.6791666666666667,
#     0.6296875,
#     0.6791666666666667]],
#   'iscrowd': 0},
#  {'id': 980,
#   'image_id': 786,
#   'category_id': 1,
#   'bbox': [389.0, 303.0, 152.0, 165.0],
#   'area': 25080.0,
#   'segmentation': [[0.6078125,
#     0.63125,
#     0.8453125,
#     0.63125,
#     0.8453125,
#     0.975,
#     0.6078125,
#     0.975]],
#   'iscrowd': 0},
#  {'id': 981,
#   'image_id': 787,
#   'category_id': 1,
#   'bbox': [216.0, 199.0, 182.0, 68.0],
#   'area': 12376.0,
#   'segmentation': [[0.3375,
#     0.41458333333333336,
#     0.621875,
#     0.41458333333333336,
#     0.621875,
#     0.55625,
#     0.3375,
#     0.55625]],
#   'iscrowd': 0},
#  {'id': 982,
#   'image_id': 788,
#   'category_id': 1,
#   'bbox': [458.0, 259.0, 77.0, 32.0],
#   'area': 2464.0,
#   'segmentation': [[0.715625,
#     0.5395833333333333,
#     0.8359375,
#     0.5395833333333333,
#     0.8359375,
#     0.60625,
#     0.715625,
#     0.60625]],
#   'iscrowd': 0},
#  {'id': 983,
#   'image_id': 789,
#   'category_id': 1,
#   'bbox': [282.0, 144.0, 101.0, 74.0],
#   'area': 7474.0,
#   'segmentation': [[0.440625,
#     0.3,
#     0.5984375,
#     0.3,
#     0.5984375,
#     0.45416666666666666,
#     0.440625,
#     0.45416666666666666]],
#   'iscrowd': 0},
#  {'id': 984,
#   'image_id': 790,
#   'category_id': 1,
#   'bbox': [475.0, 222.0, 84.0, 57.0],
#   'area': 4788.0,
#   'segmentation': [[0.7421875,
#     0.4625,
#     0.8734375,
#     0.4625,
#     0.8734375,
#     0.58125,
#     0.7421875,
#     0.58125]],
#   'iscrowd': 0},
#  {'id': 985,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [116.0, 122.0, 78.0, 91.0],
#   'area': 7098.0,
#   'segmentation': [[0.18125,
#     0.25416666666666665,
#     0.303125,
#     0.25416666666666665,
#     0.303125,
#     0.44375,
#     0.18125,
#     0.44375]],
#   'iscrowd': 0},
#  {'id': 986,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [425.0, 90.0, 99.0, 85.0],
#   'area': 8415.0,
#   'segmentation': [[0.6640625,
#     0.1875,
#     0.81875,
#     0.1875,
#     0.81875,
#     0.3645833333333333,
#     0.6640625,
#     0.3645833333333333]],
#   'iscrowd': 0},
#  {'id': 987,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [390.0, 171.0, 143.0, 144.0],
#   'area': 20592.0,
#   'segmentation': [[0.609375,
#     0.35625,
#     0.8328125,
#     0.35625,
#     0.8328125,
#     0.65625,
#     0.609375,
#     0.65625]],
#   'iscrowd': 0},
#  {'id': 988,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [413.0, 297.0, 112.0, 139.0],
#   'area': 15568.0,
#   'segmentation': [[0.6453125,
#     0.61875,
#     0.8203125,
#     0.61875,
#     0.8203125,
#     0.9083333333333333,
#     0.6453125,
#     0.9083333333333333]],
#   'iscrowd': 0},
#  {'id': 989,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [96.0, 211.0, 93.0, 113.0],
#   'area': 10509.0,
#   'segmentation': [[0.15,
#     0.4395833333333333,
#     0.2953125,
#     0.4395833333333333,
#     0.2953125,
#     0.675,
#     0.15,
#     0.675]],
#   'iscrowd': 0},
#  {'id': 990,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [84.0, 323.0, 95.0, 107.0],
#   'area': 10165.0,
#   'segmentation': [[0.13125,
#     0.6729166666666667,
#     0.2796875,
#     0.6729166666666667,
#     0.2796875,
#     0.8958333333333334,
#     0.13125,
#     0.8958333333333334]],
#   'iscrowd': 0},
#  {'id': 991,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [185.0, 180.0, 46.0, 74.0],
#   'area': 3404.0,
#   'segmentation': [[0.2890625,
#     0.375,
#     0.3609375,
#     0.375,
#     0.3609375,
#     0.5291666666666667,
#     0.2890625,
#     0.5291666666666667]],
#   'iscrowd': 0},
#  {'id': 992,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [225.0, 179.0, 52.0, 76.0],
#   'area': 3952.0,
#   'segmentation': [[0.3515625,
#     0.3729166666666667,
#     0.4328125,
#     0.3729166666666667,
#     0.4328125,
#     0.53125,
#     0.3515625,
#     0.53125]],
#   'iscrowd': 0},
#  {'id': 993,
#   'image_id': 791,
#   'category_id': 1,
#   'bbox': [175.0, 249.0, 98.0, 162.0],
#   'area': 15876.0,
#   'segmentation': [[0.2734375,
#     0.51875,
#     0.4265625,
#     0.51875,
#     0.4265625,
#     0.85625,
#     0.2734375,
#     0.85625]],
#   'iscrowd': 0},
#  {'id': 994,
#   'image_id': 792,
#   'category_id': 0,
#   'bbox': [134.0, 88.0, 379.0, 229.0],
#   'area': 86791.0,
#   'segmentation': [[0.209375,
#     0.18333333333333332,
#     0.8015625,
#     0.18333333333333332,
#     0.8015625,
#     0.6604166666666667,
#     0.209375,
#     0.6604166666666667]],
#   'iscrowd': 0},
#  {'id': 995,
#   'image_id': 793,
#   'category_id': 1,
#   'bbox': [246.0, 198.0, 120.0, 46.0],
#   'area': 5520.0,
#   'segmentation': [[0.384375,
#     0.4125,
#     0.571875,
#     0.4125,
#     0.571875,
#     0.5083333333333333,
#     0.384375,
#     0.5083333333333333]],
#   'iscrowd': 0},
#  {'id': 996,
#   'image_id': 794,
#   'category_id': 1,
#   'bbox': [232.0, 84.0, 175.0, 67.0],
#   'area': 11725.0,
#   'segmentation': [[0.3625,
#     0.175,
#     0.6359375,
#     0.175,
#     0.6359375,
#     0.3145833333333333,
#     0.3625,
#     0.3145833333333333]],
#   'iscrowd': 0},
#  {'id': 997,
#   'image_id': 795,
#   'category_id': 1,
#   'bbox': [118.0, 59.0, 395.0, 325.0],
#   'area': 128375.0,
#   'segmentation': [[0.184375,
#     0.12291666666666666,
#     0.8015625,
#     0.12291666666666666,
#     0.8015625,
#     0.8,
#     0.184375,
#     0.8]],
#   'iscrowd': 0},
#  {'id': 998,
#   'image_id': 796,
#   'category_id': 1,
#   'bbox': [95.0, 85.0, 446.0, 303.0],
#   'area': 135138.0,
#   'segmentation': [[0.1484375,
#     0.17708333333333334,
#     0.8453125,
#     0.17708333333333334,
#     0.8453125,
#     0.8083333333333333,
#     0.1484375,
#     0.8083333333333333]],
#   'iscrowd': 0},
#  {'id': 999,
#   'image_id': 797,
#   'category_id': 1,
#   'bbox': [80.0, 68.0, 478.0, 341.0],
#   'area': 162998.0,
#   'segmentation': [[0.125,
#     0.14166666666666666,
#     0.871875,
#     0.14166666666666666,
#     0.871875,
#     0.8520833333333333,
#     0.125,
#     0.8520833333333333]],
#   'iscrowd': 0},
#  {'id': 1000,
#   'image_id': 798,
#   'category_id': 1,
#   'bbox': [222.0, 262.0, 94.0, 50.0],
#   'area': 4700.0,
#   'segmentation': [[0.346875,
#     0.5458333333333333,
#     0.49375,
#     0.5458333333333333,
#     0.49375,
#     0.65,
#     0.346875,
#     0.65]],
#   'iscrowd': 0},
#  ...]

# %%
import torch

print(output_path)
train = torch.load(os.path.join(output_path, "train.cache"))
# Out:
# /home/cmurphy/datasets/toma/box-detection-yolo
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[30], line 3
#       1 import torch
#       2 print(output_path)
# ----> 3 train = torch.load(os.path.join(output_path, "train.cache"))
#
# File ~/repos/YOLO/.venv/lib/python3.12/site-packages/torch/serialization.py:1470, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1462                 return _load(
#    1463                     opened_zipfile,
#    1464                     map_location,
#    (...)   1467                     **pickle_load_args,
#    1468                 )
#    1469             except pickle.UnpicklingError as e:
# -> 1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471         return _load(
#    1472             opened_zipfile,
#    1473             map_location,
#    (...)   1476             **pickle_load_args,
#    1477         )
#    1478 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL pathlib.PosixPath was not an allowed global by default. Please use `torch.serialization.add_safe_globals([PosixPath])` or the `torch.serialization.safe_globals([PosixPath])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %%
torch.load(
    "/home/cmurphy/datasets/toma/box-detection-yolo/train.cache", weights_only=False
)
# Out:
# [(PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000000.jpg'),
#   tensor([[1.0000e+00, 8.5449e-04, 9.6354e-04, 1.1206e-03, 1.1632e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000001.jpg'),
#   tensor([[1.0000e+00, 3.2959e-04, 6.9444e-04, 1.3525e-03, 1.8099e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000002.jpg'),
#   tensor([[0.0000e+00, 2.1973e-04, 3.9063e-05, 1.3525e-03, 2.0833e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000003.jpg'),
#   tensor([[1.0000e+00, 0.0000e+00, 2.1973e-04, 1.5576e-03, 1.3330e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000004.jpg'),
#   tensor([[0.0000, 0.0004, 0.0009, 0.0008, 0.0020]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000005.jpg'),
#   tensor([[0.0000, 0.0000, 0.0003, 0.0011, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000006.jpg'),
#   tensor([[1.0000e+00, 1.0156e-03, 7.5521e-04, 1.3477e-03, 1.0026e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000007.jpg'),
#   tensor([[0.0000e+00, 7.6416e-04, 6.2934e-04, 9.4238e-04, 8.2465e-04],
#           [1.0000e+00, 5.3711e-05, 4.6007e-04, 1.6113e-04, 5.5122e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000008.jpg'),
#   tensor([[0.0000, 0.0003, 0.0010, 0.0008, 0.0015]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000009.jpg'),
#   tensor([[1.0000e+00, 5.1270e-04, 7.2483e-04, 8.2275e-04, 9.2882e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000010.jpg'),
#   tensor([[1.0000e+00, 3.6621e-04, 5.4253e-04, 1.1621e-03, 1.0330e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000011.jpg'),
#   tensor([[1.0000e+00, 4.3945e-04, 7.2483e-04, 8.9111e-04, 9.8958e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000012.jpg'),
#   tensor([[1.0000e+00, 3.7109e-04, 3.8194e-04, 7.5195e-04, 8.7240e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000013.jpg'),
#   tensor([[0.0000, 0.0004, 0.0007, 0.0011, 0.0011]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000014.jpg'),
#   tensor([[1.0000e+00, 4.4922e-04, 2.2569e-04, 1.1353e-03, 1.0981e-03],
#           [1.0000e+00, 4.1504e-04, 8.7240e-04, 1.2061e-03, 2.0226e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000015.jpg'),
#   tensor([[0.0000e+00, 1.4648e-05, 4.6007e-04, 1.1133e-03, 1.8186e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000016.jpg'),
#   tensor([[1.0000e+00, 4.2236e-04, 1.2587e-03, 5.4199e-04, 1.7361e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000017.jpg'),
#   tensor([[1.0000e+00, 4.3457e-04, 1.1502e-03, 8.2520e-04, 1.4280e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000018.jpg'),
#   tensor([[1.0000e+00, 2.6367e-04, 1.6493e-04, 1.3086e-03, 1.8012e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000019.jpg'),
#   tensor([[0.0000e+00, 3.4180e-05, 5.9462e-04, 1.5625e-03, 1.8707e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000020.jpg'),
#   tensor([[1.0000e+00, 5.3955e-04, 3.9497e-04, 9.6436e-04, 6.5538e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000021.jpg'),
#   tensor([[1.0000e+00, 4.1260e-04, 1.1068e-03, 8.7158e-04, 1.6970e-03],
#           [0.0000e+00, 3.3447e-04, 5.2083e-04, 9.9854e-04, 1.2457e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000022.jpg'),
#   tensor([[1.0000e+00, 8.3496e-04, 5.6858e-04, 1.2134e-03, 8.0729e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000023.jpg'),
#   tensor([[1.0000e+00, 2.2217e-04, 2.3003e-04, 1.3330e-03, 1.8273e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000024.jpg'),
#   tensor([[1.0000e+00, 6.8359e-04, 9.8958e-04, 1.0791e-03, 1.2977e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000025.jpg'),
#   tensor([[1.0000e+00, 5.0049e-04, 9.9826e-05, 1.0352e-03, 1.8707e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000026.jpg'),
#   tensor([[0.0000e+00, 6.6650e-04, 7.0747e-04, 1.0327e-03, 1.0677e-03],
#           [1.0000e+00, 0.0000e+00, 6.3368e-04, 5.8594e-05, 7.2917e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000027.jpg'),
#   tensor([[0.0000e+00, 1.1328e-03, 3.0382e-05, 1.5601e-03, 4.2969e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000028.jpg'),
#   tensor([[0.0000, 0.0004, 0.0007, 0.0011, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000029.jpg'),
#   tensor([[1.0000e+00, 8.9111e-04, 9.2882e-04, 1.3550e-03, 1.2630e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000030.jpg'),
#   tensor([[1.0000e+00, 1.5137e-04, 4.9479e-04, 5.2246e-04, 7.3785e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000031.jpg'),
#   tensor([[0.0000, 0.0002, 0.0001, 0.0012, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000032.jpg'),
#   tensor([[1.0000e+00, 4.8828e-04, 3.5156e-04, 1.0498e-03, 6.3368e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000033.jpg'),
#   tensor([[0.0000, 0.0006, 0.0005, 0.0013, 0.0010]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000034.jpg'),
#   tensor([[0.0000, 0.0000, 0.0007, 0.0009, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000035.jpg'),
#   tensor([[1.0000e+00, 1.1963e-03, 7.8993e-04, 1.4673e-03, 1.0243e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000036.jpg'),
#   tensor([[1.0000e+00, 6.7616e-04, 4.6158e-04, 8.0776e-04, 9.2697e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000037.jpg'),
#   tensor([[1.0000e+00, 8.1055e-04, 1.1241e-03, 1.2280e-03, 1.5061e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000038.jpg'),
#   tensor([[0.0000, 0.0004, 0.0001, 0.0009, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000039.jpg'),
#   tensor([[1.0000e+00, 4.7363e-04, 7.7257e-04, 8.3984e-04, 9.7222e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000040.jpg'),
#   tensor([[0.0000, 0.0003, 0.0000, 0.0014, 0.0009]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000041.jpg'),
#   tensor([[1.0000e+00, 6.4209e-04, 1.0547e-03, 9.4482e-04, 1.2674e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000042.jpg'),
#   tensor([[0.0000, 0.0002, 0.0005, 0.0015, 0.0021]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000043.jpg'),
#   tensor([[0.0000, 0.0000, 0.0005, 0.0011, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000044.jpg'),
#   tensor([[1.0000e+00, 1.3184e-04, 5.4253e-04, 1.3867e-03, 1.7057e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000045.jpg'),
#   tensor([[0.0000e+00, 6.5918e-05, 3.9063e-05, 1.5625e-03, 2.0790e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000046.jpg'),
#   tensor([[1.0000e+00, 1.9531e-04, 2.8212e-04, 1.3818e-03, 1.7752e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000047.jpg'),
#   tensor([[1.0000e+00, 8.4229e-04, 3.8628e-04, 1.2158e-03, 6.5972e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000048.jpg'),
#   tensor([[1.0000e+00, 2.9785e-04, 4.6007e-04, 7.5439e-04, 8.3333e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000049.jpg'),
#   tensor([[0.0000, 0.0006, 0.0002, 0.0011, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000050.jpg'),
#   tensor([[1.0000e+00, 4.1260e-04, 4.7743e-04, 7.7637e-04, 7.3785e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000051.jpg'),
#   tensor([[1.0000e+00, 8.5205e-04, 4.8611e-04, 1.1060e-03, 1.4193e-03],
#           [1.0000e+00, 9.8633e-04, 6.0764e-05, 1.3354e-03, 1.2240e-03],
#           [1.0000e+00, 6.5430e-04, 1.0503e-03, 1.2671e-03, 1.9054e-03],
#           [1.0000e+00, 6.3477e-04, 1.8663e-04, 9.1553e-04, 1.2023e-03],
#           [1.0000e+00, 3.2471e-04, 2.6476e-04, 6.1279e-04, 9.2882e-04],
#           [1.0000e+00, 2.1240e-04, 7.5087e-04, 6.5674e-04, 1.9444e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000052.jpg'),
#   tensor([[0.0000, 0.0002, 0.0004, 0.0013, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000053.jpg'),
#   tensor([[1.0000e+00, 5.8594e-04, 1.0243e-03, 8.7158e-04, 1.2370e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000054.jpg'),
#   tensor([[1.0000e+00, 5.7861e-04, 1.1068e-03, 8.9355e-04, 1.4149e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000055.jpg'),
#   tensor([[0.0000, 0.0002, 0.0003, 0.0012, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000056.jpg'),
#   tensor([[0.0000, 0.0004, 0.0005, 0.0011, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000057.jpg'),
#   tensor([[1.0000e+00, 9.5459e-04, 3.5590e-04, 1.0620e-03, 4.7743e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000058.jpg'),
#   tensor([[0.0000, 0.0002, 0.0001, 0.0014, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000059.jpg'),
#   tensor([[1.0000e+00, 1.8555e-04, 6.8142e-04, 6.4697e-04, 1.0286e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000060.jpg'),
#   tensor([[1.0000e+00, 0.0000e+00, 3.9063e-05, 1.5601e-03, 1.4648e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000061.jpg'),
#   tensor([[0.0000, 0.0002, 0.0004, 0.0013, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000062.jpg'),
#   tensor([[0.0000, 0.0007, 0.0013, 0.0010, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000063.jpg'),
#   tensor([[0.0000, 0.0003, 0.0005, 0.0013, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000064.jpg'),
#   tensor([[1.0000e+00, 3.6865e-04, 5.2083e-04, 1.2036e-03, 1.6493e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000065.jpg'),
#   tensor([[1.0000e+00, 5.9082e-04, 1.3281e-03, 1.3721e-03, 2.0833e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000066.jpg'),
#   tensor([[1.0000e+00, 1.9531e-04, 3.9931e-04, 4.3945e-04, 7.2483e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000067.jpg'),
#   tensor([[0.0000, 0.0007, 0.0007, 0.0011, 0.0011]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000068.jpg'),
#   tensor([[1.0000e+00, 1.7822e-04, 2.3872e-04, 1.1743e-03, 1.3064e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000069.jpg'),
#   tensor([[1.0000e+00, 6.6650e-04, 4.2969e-04, 1.3623e-03, 1.0503e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000070.jpg'),
#   tensor([[1.0000e+00, 8.1787e-04, 8.9410e-04, 1.0132e-03, 1.0720e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000071.jpg'),
#   tensor([[1.0000e+00, 8.4717e-04, 1.2153e-03, 1.2134e-03, 1.5191e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000072.jpg'),
#   tensor([[1.0000e+00, 1.1230e-04, 4.3403e-04, 1.4746e-03, 2.0703e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000073.jpg'),
#   tensor([[0.0000, 0.0004, 0.0004, 0.0012, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000074.jpg'),
#   tensor([[0.0000, 0.0002, 0.0004, 0.0014, 0.0017]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000075.jpg'),
#   tensor([[0.0000, 0.0002, 0.0003, 0.0015, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000076.jpg'),
#   tensor([[0.0000, 0.0002, 0.0002, 0.0013, 0.0020]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000077.jpg'),
#   tensor([[1.0000e+00, 4.9316e-04, 1.9097e-04, 1.1548e-03, 5.4688e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000078.jpg'),
#   tensor([[1.0000e+00, 3.9063e-05, 8.2465e-05, 1.2598e-03, 7.3351e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000079.jpg'),
#   tensor([[0.0000, 0.0004, 0.0001, 0.0011, 0.0006]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000080.jpg'),
#   tensor([[0.0000, 0.0006, 0.0009, 0.0010, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000081.jpg'),
#   tensor([[0.0000, 0.0006, 0.0010, 0.0009, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000082.jpg'),
#   tensor([[1.0000e+00, 3.5889e-04, 4.3837e-04, 1.3354e-03, 2.0095e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000083.jpg'),
#   tensor([[1.0000e+00, 2.2461e-04, 2.6476e-04, 1.2183e-03, 1.3151e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000084.jpg'),
#   tensor([[1.0000e+00, 7.5195e-04, 5.8594e-04, 1.0522e-03, 8.2031e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000085.jpg'),
#   tensor([[0.0000, 0.0005, 0.0011, 0.0007, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000086.jpg'),
#   tensor([[1.0000e+00, 4.6875e-04, 3.9497e-04, 1.0376e-03, 7.3351e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000087.jpg'),
#   tensor([[1.0000e+00, 8.1543e-04, 8.6806e-04, 1.5405e-03, 1.7361e-03],
#           [1.0000e+00, 1.9287e-04, 9.2448e-04, 8.3740e-04, 1.7014e-03],
#           [1.0000e+00, 4.3945e-04, 4.2535e-04, 1.1108e-03, 1.1502e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000088.jpg'),
#   tensor([[1.0000e+00, 1.0352e-03, 7.9861e-04, 1.2158e-03, 1.2804e-03],
#           [1.0000e+00, 8.5449e-05, 8.3333e-04, 5.9082e-04, 1.3628e-03],
#           [1.0000e+00, 5.7617e-04, 8.2465e-04, 1.0474e-03, 1.3498e-03],
#           [1.0000e+00, 4.3457e-04, 1.2457e-03, 9.4727e-04, 1.8924e-03],
#           [1.0000e+00, 9.3994e-04, 1.2674e-03, 1.4355e-03, 1.9054e-03],
#           [1.0000e+00, 3.4180e-05, 1.2760e-03, 5.5176e-04, 1.9965e-03],
#           [1.0000e+00, 3.8086e-04, 4.3403e-05, 1.0376e-03, 9.0278e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000089.jpg'),
#   tensor([[1.0000e+00, 1.6846e-04, 3.9931e-04, 4.2236e-04, 7.2049e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000090.jpg'),
#   tensor([[1.0000e+00, 0.0000e+00, 3.9551e-04, 1.5625e-03, 1.1646e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000091.jpg'),
#   tensor([[1.0000e+00, 3.1494e-04, 1.0026e-03, 8.6426e-04, 1.8880e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000092.jpg'),
#   tensor([[0.0000e+00, 2.8564e-04, 1.3021e-05, 1.3770e-03, 9.9826e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000093.jpg'),
#   tensor([[0.0000, 0.0000, 0.0006, 0.0012, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000094.jpg'),
#   tensor([[0.0000, 0.0006, 0.0006, 0.0016, 0.0015]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000095.jpg'),
#   tensor([[1.0000e+00, 5.6885e-04, 5.1025e-04, 9.9365e-04, 1.0498e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000096.jpg'),
#   tensor([[0.0000, 0.0002, 0.0006, 0.0015, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000097.jpg'),
#   tensor([[0.0000, 0.0000, 0.0006, 0.0016, 0.0020]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000098.jpg'),
#   tensor([[1.0000e+00, 1.4648e-04, 1.3889e-04, 1.4087e-03, 1.8533e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000099.jpg'),
#   tensor([[0.0000e+00, 2.1973e-05, 3.1738e-05, 1.5576e-03, 1.5088e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000100.jpg'),
#   tensor([[1.0000e+00, 2.9785e-04, 4.2969e-04, 7.5439e-04, 8.1597e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000101.jpg'),
#   tensor([[1.0000e+00, 3.5889e-04, 5.5556e-04, 1.1572e-03, 1.0590e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000102.jpg'),
#   tensor([[0.0000e+00, 1.9531e-04, 3.9063e-05, 1.3770e-03, 1.1938e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000103.jpg'),
#   tensor([[1.0000e+00, 3.2227e-04, 1.1806e-03, 7.1777e-04, 1.4019e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000104.jpg'),
#   tensor([[1.0000e+00, 5.6152e-04, 7.8125e-04, 8.3252e-04, 9.8090e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000105.jpg'),
#   tensor([[0.0000, 0.0004, 0.0004, 0.0014, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000106.jpg'),
#   tensor([[1.0000e+00, 4.0039e-04, 1.2283e-03, 7.3242e-04, 1.4540e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000107.jpg'),
#   tensor([[1.0000e+00, 7.6660e-04, 6.5538e-04, 1.0376e-03, 8.8108e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000108.jpg'),
#   tensor([[1.0000e+00, 4.2725e-04, 1.2847e-03, 7.3975e-04, 1.4931e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000109.jpg'),
#   tensor([[0.0000, 0.0006, 0.0018, 0.0010, 0.0021]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000110.jpg'),
#   tensor([[1.0000e+00, 1.9531e-04, 2.1701e-05, 1.3843e-03, 2.0790e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000111.jpg'),
#   tensor([[0.0000, 0.0004, 0.0002, 0.0011, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000112.jpg'),
#   tensor([[1.0000e+00, 5.0781e-04, 9.5486e-04, 9.8145e-04, 1.2196e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000113.jpg'),
#   tensor([[1.0000e+00, 2.5391e-04, 8.2031e-04, 7.2754e-04, 1.2066e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000114.jpg'),
#   tensor([[1.0000e+00, 4.6387e-04, 1.2283e-03, 7.5684e-04, 1.4236e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000115.jpg'),
#   tensor([[0.0000e+00, 3.4180e-04, 4.6441e-04, 1.2988e-03, 1.8316e-03],
#           [1.0000e+00, 2.5391e-04, 2.5174e-04, 1.1035e-03, 1.2674e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000116.jpg'),
#   tensor([[1.0000e+00, 8.6182e-04, 3.8628e-04, 1.3623e-03, 6.6406e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000117.jpg'),
#   tensor([[1.0000e+00, 3.9063e-04, 3.7760e-04, 1.0522e-03, 9.5920e-04],
#           [1.0000e+00, 3.0762e-04, 7.2049e-04, 1.1255e-03, 1.4106e-03],
#           [1.0000e+00, 1.4893e-04, 9.3316e-04, 1.3281e-03, 1.8533e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000118.jpg'),
#   tensor([[1.0000e+00, 7.6904e-04, 3.9497e-04, 1.2402e-03, 7.2049e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000119.jpg'),
#   tensor([[0.0000, 0.0004, 0.0004, 0.0014, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000120.jpg'),
#   tensor([[0.0000, 0.0006, 0.0002, 0.0009, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000121.jpg'),
#   tensor([[0.0000, 0.0006, 0.0010, 0.0012, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000122.jpg'),
#   tensor([[0.0000, 0.0002, 0.0002, 0.0012, 0.0020]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000123.jpg'),
#   tensor([[0.0000, 0.0007, 0.0009, 0.0009, 0.0011]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000124.jpg'),
#   tensor([], size=(0, 5)),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000125.jpg'),
#   tensor([[1.0000e+00, 4.1260e-04, 3.4722e-04, 1.1475e-03, 1.6840e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000126.jpg'),
#   tensor([[1.0000e+00, 2.3682e-04, 8.2899e-04, 7.1533e-04, 1.2283e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000127.jpg'),
#   tensor([[0.0000, 0.0004, 0.0005, 0.0011, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000128.jpg'),
#   tensor([[0.0000, 0.0002, 0.0003, 0.0009, 0.0009]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000129.jpg'),
#   tensor([[1.0000e+00, 7.3730e-04, 7.1615e-04, 9.9365e-04, 9.2014e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000130.jpg'),
#   tensor([[0.0000, 0.0000, 0.0005, 0.0015, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000131.jpg'),
#   tensor([[1.0000e+00, 1.9531e-04, 1.1285e-04, 1.1060e-03, 1.0460e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000132.jpg'),
#   tensor([[1.0000e+00, 5.6152e-05, 9.7656e-05, 1.4502e-03, 1.4648e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000133.jpg'),
#   tensor([[1.0000e+00, 3.6133e-04, 3.8194e-04, 1.1523e-03, 1.6970e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000134.jpg'),
#   tensor([[1.0000e+00, 6.7383e-04, 9.5920e-04, 1.1816e-03, 1.3021e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000135.jpg'),
#   tensor([[0.0000, 0.0004, 0.0004, 0.0012, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000136.jpg'),
#   tensor([[1.0000e+00, 3.6133e-04, 8.2465e-04, 7.8369e-04, 1.0720e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000137.jpg'),
#   tensor([[1.0000e+00, 1.0327e-03, 2.3872e-04, 1.3672e-03, 5.1649e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000138.jpg'),
#   tensor([[1.0000e+00, 1.1133e-03, 2.2135e-04, 1.5576e-03, 4.9045e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000139.jpg'),
#   tensor([], size=(0, 5)),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000140.jpg'),
#   tensor([[1.0000e+00, 6.6162e-04, 9.6354e-04, 1.0498e-03, 1.2543e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000141.jpg'),
#   tensor([[1.0000e+00, 2.5635e-04, 2.0399e-04, 1.3257e-03, 1.8056e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000142.jpg'),
#   tensor([[1.0000e+00, 5.1025e-04, 7.6823e-04, 8.5693e-04, 9.6354e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000143.jpg'),
#   tensor([[1.0000e+00, 3.3936e-04, 1.6602e-04, 1.3843e-03, 1.4307e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000144.jpg'),
#   tensor([[1.0000e+00, 4.3011e-04, 1.5678e-03, 5.5695e-04, 1.9417e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000145.jpg'),
#   tensor([[1.0000e+00, 7.2021e-04, 7.0313e-04, 1.0376e-03, 8.9844e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000146.jpg'),
#   tensor([[0.0000e+00, 6.4453e-04, 7.3785e-05, 1.0376e-03, 1.2934e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000147.jpg'),
#   tensor([[0.0000e+00, 8.0566e-05, 5.6152e-05, 1.4966e-03, 1.5283e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000148.jpg'),
#   tensor([[1.0000e+00, 7.5928e-04, 3.2986e-04, 1.1182e-03, 5.8594e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000149.jpg'),
#   tensor([[1.0000e+00, 2.3926e-04, 1.3021e-04, 1.2842e-03, 1.9488e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000150.jpg'),
#   tensor([[1.0000e+00, 2.7370e-04, 4.2343e-04, 4.2629e-04, 9.4223e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000151.jpg'),
#   tensor([[0.0000, 0.0005, 0.0008, 0.0010, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000152.jpg'),
#   tensor([[1.0000e+00, 1.5625e-04, 2.6910e-04, 1.1548e-03, 1.3108e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000153.jpg'),
#   tensor([[0.0000, 0.0008, 0.0019, 0.0011, 0.0021]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000154.jpg'),
#   tensor([[1.0000e+00, 1.0107e-03, 6.4941e-04, 1.3672e-03, 1.3477e-03],
#           [1.0000e+00, 1.1450e-03, 1.1230e-04, 1.3330e-03, 6.7139e-04],
#           [1.0000e+00, 8.8623e-04, 1.0254e-04, 1.1475e-03, 7.4463e-04],
#           [1.0000e+00, 2.0020e-04, 3.1738e-05, 5.7373e-04, 1.2183e-03],
#           [1.0000e+00, 5.6641e-04, 8.3008e-05, 8.7402e-04, 6.4209e-04],
#           [1.0000e+00, 6.8359e-04, 4.4678e-04, 8.8623e-04, 6.1523e-04],
#           [1.0000e+00, 6.1523e-04, 6.0791e-04, 1.0059e-03, 8.3008e-04],
#           [1.0000e+00, 6.8359e-04, 8.0566e-04, 1.0254e-03, 1.2280e-03],
#           [1.0000e+00, 8.0322e-04, 1.1719e-03, 1.1182e-03, 1.4307e-03],
#           [0.0000e+00, 3.7842e-04, 1.1011e-03, 8.0811e-04, 1.5332e-03],
#           [0.0000e+00, 3.5645e-04, 6.2012e-04, 6.7139e-04, 1.3110e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000155.jpg'),
#   tensor([[1.0000e+00, 7.4707e-04, 5.1215e-04, 1.1792e-03, 8.0729e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000156.jpg'),
#   tensor([[1.0000e+00, 7.7881e-04, 1.0113e-03, 1.1621e-03, 1.1936e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000157.jpg'),
#   tensor([[0.0000, 0.0004, 0.0002, 0.0013, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000158.jpg'),
#   tensor([[1.0000e+00, 1.0742e-04, 1.6059e-04, 1.5259e-03, 1.9965e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000159.jpg'),
#   tensor([[1.0000e+00, 7.4463e-04, 1.0278e-03, 9.4727e-04, 1.2256e-03],
#           [1.0000e+00, 3.5645e-04, 8.4229e-04, 8.1787e-04, 1.5039e-03],
#           [1.0000e+00, 7.2998e-04, 1.1865e-03, 9.5459e-04, 1.3599e-03],
#           [1.0000e+00, 7.4463e-04, 1.3477e-03, 9.2285e-04, 1.4941e-03],
#           [1.0000e+00, 7.9590e-04, 3.1738e-05, 1.0449e-03, 6.5430e-04],
#           [1.0000e+00, 5.1758e-04, 2.0020e-04, 8.1299e-04, 8.9111e-04],
#           [1.0000e+00, 8.1299e-04, 6.2988e-04, 1.2329e-03, 1.4673e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000160.jpg'),
#   tensor([[1.0000e+00, 9.0332e-04, 1.4063e-03, 1.3037e-03, 1.6710e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000161.jpg'),
#   tensor([[1.0000e+00, 7.6660e-04, 9.2882e-04, 9.7900e-04, 1.0720e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000162.jpg'),
#   tensor([[1.0000e+00, 1.6113e-04, 4.9045e-04, 1.3525e-03, 1.5234e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000163.jpg'),
#   tensor([[1.0000e+00, 3.7598e-04, 4.2535e-04, 1.4331e-03, 1.1762e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000164.jpg'),
#   tensor([[1.0000e+00, 7.0801e-04, 5.2951e-04, 1.1401e-03, 8.2899e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000165.jpg'),
#   tensor([[1.0000e+00, 2.9785e-04, 7.9861e-04, 1.5356e-03, 1.7882e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000166.jpg'),
#   tensor([[0.0000, 0.0003, 0.0005, 0.0014, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000167.jpg'),
#   tensor([[1.0000, 0.0011, 0.0014, 0.0014, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000168.jpg'),
#   tensor([[0.0000, 0.0007, 0.0010, 0.0012, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000169.jpg'),
#   tensor([[0.0000, 0.0006, 0.0005, 0.0013, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000170.jpg'),
#   tensor([[0.0000, 0.0003, 0.0009, 0.0016, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000171.jpg'),
#   tensor([[1.0000e+00, 9.1064e-04, 3.5590e-04, 1.4624e-03, 6.2500e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000172.jpg'),
#   tensor([[1.0000e+00, 5.1758e-04, 6.9010e-04, 7.4707e-04, 1.7578e-03],
#           [0.0000e+00, 7.5195e-04, 9.2882e-04, 1.1060e-03, 1.9054e-03],
#           [1.0000e+00, 1.4893e-04, 1.0851e-04, 7.0068e-04, 1.5929e-03],
#           [0.0000e+00, 7.0312e-04, 8.6806e-06, 1.4160e-03, 1.6797e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000173.jpg'),
#   tensor([[1.0000e+00, 5.7129e-04, 1.1589e-03, 7.4463e-04, 1.2977e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000174.jpg'),
#   tensor([], size=(0, 5)),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000175.jpg'),
#   tensor([[1.0000e+00, 4.9072e-04, 1.1328e-03, 7.9102e-04, 1.3542e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000176.jpg'),
#   tensor([[0.0000, 0.0004, 0.0006, 0.0013, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000177.jpg'),
#   tensor([[0.0000, 0.0003, 0.0004, 0.0012, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000178.jpg'),
#   tensor([[1.0000e+00, 4.6631e-04, 9.2448e-04, 1.1182e-03, 2.0052e-03],
#           [1.0000e+00, 5.2979e-04, 2.5608e-04, 1.1914e-03, 1.0851e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000179.jpg'),
#   tensor([[1.0000e+00, 1.0010e-04, 7.3785e-05, 1.3208e-03, 1.7708e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000180.jpg'),
#   tensor([[0.0000, 0.0007, 0.0002, 0.0012, 0.0017]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000181.jpg'),
#   tensor([[1.0000e+00, 4.4922e-04, 1.1111e-03, 6.6650e-04, 1.2760e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000182.jpg'),
#   tensor([[0.0000, 0.0003, 0.0007, 0.0011, 0.0017]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000183.jpg'),
#   tensor([[0.0000, 0.0006, 0.0006, 0.0011, 0.0011]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000184.jpg'),
#   tensor([[1.0000e+00, 6.4453e-04, 1.1285e-03, 1.2915e-03, 2.0833e-03],
#           [1.0000e+00, 9.2041e-04, 1.0200e-03, 1.3574e-03, 1.8967e-03],
#           [1.0000e+00, 1.8799e-04, 1.0503e-03, 6.4941e-04, 2.0833e-03],
#           [1.0000e+00, 4.0039e-04, 4.9913e-04, 9.5703e-04, 1.2674e-03],
#           [1.0000e+00, 9.3750e-04, 5.2083e-04, 1.0767e-03, 1.1632e-03],
#           [1.0000e+00, 5.2246e-04, 3.9063e-05, 9.5703e-04, 5.8160e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000185.jpg'),
#   tensor([[0.0000, 0.0007, 0.0010, 0.0011, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000186.jpg'),
#   tensor([[1.0000e+00, 5.5908e-04, 6.0764e-05, 1.5576e-03, 9.5486e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000187.jpg'),
#   tensor([[0.0000, 0.0002, 0.0004, 0.0010, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000188.jpg'),
#   tensor([[0.0000e+00, 2.4414e-05, 4.7743e-05, 1.5356e-03, 2.0443e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000189.jpg'),
#   tensor([[0.0000, 0.0009, 0.0011, 0.0012, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000190.jpg'),
#   tensor([[1.0000e+00, 4.0039e-04, 1.2283e-03, 7.3242e-04, 1.4540e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000191.jpg'),
#   tensor([[1.0000e+00, 2.7588e-04, 1.2023e-03, 1.0181e-03, 1.6016e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000192.jpg'),
#   tensor([[1.0000e+00, 4.8828e-06, 3.4288e-04, 1.3428e-03, 1.6536e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000193.jpg'),
#   tensor([[1.0000e+00, 3.0029e-04, 9.4184e-04, 1.3770e-03, 1.9531e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000194.jpg'),
#   tensor([[1.0000e+00, 3.8818e-04, 6.5104e-05, 1.1841e-03, 2.0443e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000195.jpg'),
#   tensor([[1.0000e+00, 9.7900e-04, 6.6840e-04, 1.3647e-03, 1.0200e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000196.jpg'),
#   tensor([[0.0000, 0.0004, 0.0002, 0.0011, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000197.jpg'),
#   tensor([[0.0000, 0.0007, 0.0002, 0.0014, 0.0009]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000198.jpg'),
#   tensor([[1.0000e+00, 9.3018e-04, 1.0590e-03, 1.1743e-03, 1.2543e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000199.jpg'),
#   tensor([[0.0000, 0.0006, 0.0010, 0.0012, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000200.jpg'),
#   tensor([[0.0000, 0.0006, 0.0010, 0.0010, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000201.jpg'),
#   tensor([[0.0000, 0.0003, 0.0002, 0.0009, 0.0006]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000202.jpg'),
#   tensor([[1.0000e+00, 6.1035e-04, 8.9844e-04, 1.2793e-03, 1.2196e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000203.jpg'),
#   tensor([[1.0000e+00, 3.2227e-04, 7.3351e-04, 7.4463e-04, 1.0503e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000204.jpg'),
#   tensor([[0.0000, 0.0002, 0.0002, 0.0014, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000205.jpg'),
#   tensor([[1.0000e+00, 2.1240e-04, 3.7760e-04, 1.3110e-03, 1.2587e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000206.jpg'),
#   tensor([[0.0000, 0.0004, 0.0007, 0.0011, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000207.jpg'),
#   tensor([[0.0000, 0.0003, 0.0012, 0.0016, 0.0021]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000208.jpg'),
#   tensor([[1.0000e+00, 9.1553e-04, 5.1215e-04, 1.3525e-03, 8.7240e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000209.jpg'),
#   tensor([[0.0000, 0.0003, 0.0007, 0.0006, 0.0008]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000210.jpg'),
#   tensor([], size=(0, 5)),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000211.jpg'),
#   tensor([[1.0000e+00, 1.1060e-03, 1.6927e-04, 1.5552e-03, 4.5573e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000212.jpg'),
#   tensor([[1.0000e+00, 6.9336e-04, 6.0764e-04, 9.4971e-04, 8.0295e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000213.jpg'),
#   tensor([[1.0000e+00, 7.4707e-04, 5.4253e-04, 1.4233e-03, 9.4184e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000214.jpg'),
#   tensor([[0.0000e+00, 3.6377e-04, 6.9444e-05, 9.5703e-04, 1.3585e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000215.jpg'),
#   tensor([[0.0000, 0.0003, 0.0002, 0.0009, 0.0007]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000216.jpg'),
#   tensor([[1.0000e+00, 6.5918e-05, 1.6602e-04, 1.5234e-03, 1.3965e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000217.jpg'),
#   tensor([[0.0000, 0.0004, 0.0003, 0.0012, 0.0015]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000218.jpg'),
#   tensor([[1.0000e+00, 1.2207e-03, 9.2882e-04, 1.3647e-03, 1.2023e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000219.jpg'),
#   tensor([[1.0000e+00, 7.3242e-06, 8.0566e-05, 6.4453e-04, 7.6416e-04],
#           [1.0000e+00, 8.2031e-04, 6.1035e-05, 1.5088e-03, 1.0181e-03],
#           [0.0000e+00, 7.5684e-05, 9.7656e-04, 5.7129e-04, 1.4844e-03],
#           [1.0000e+00, 9.3994e-04, 1.1768e-03, 1.4111e-03, 1.4771e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000220.jpg'),
#   tensor([[1.0000e+00, 3.9551e-04, 4.1233e-04, 8.2764e-04, 6.3802e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000221.jpg'),
#   tensor([[1.0000, 0.0012, 0.0011, 0.0014, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000222.jpg'),
#   tensor([[1.0000e+00, 2.6123e-04, 4.8096e-04, 1.2329e-03, 1.2231e-03],
#           [0.0000e+00, 1.0937e-03, 1.1694e-03, 1.5308e-03, 1.5308e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000223.jpg'),
#   tensor([[1.0000e+00, 5.8350e-04, 4.6441e-04, 1.0010e-03, 7.9427e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000224.jpg'),
#   tensor([[0.0000, 0.0009, 0.0001, 0.0015, 0.0006]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000225.jpg'),
#   tensor([[1.0000e+00, 2.2461e-04, 9.1146e-05, 1.3574e-03, 2.0790e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000226.jpg'),
#   tensor([[1.0000e+00, 6.3477e-04, 8.5938e-04, 9.7168e-04, 1.1024e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000227.jpg'),
#   tensor([[1.0000e+00, 5.5176e-04, 8.0729e-04, 8.1543e-04, 1.0200e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000228.jpg'),
#   tensor([[0.0000, 0.0006, 0.0008, 0.0011, 0.0015]], dtype=torch.float64),
#   0.0),
# ...
#   tensor([[1.0000e+00, 4.3701e-04, 3.3854e-04, 1.2866e-03, 9.7656e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000928.jpg'),
#   tensor([[0.0000, 0.0001, 0.0004, 0.0014, 0.0017]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000929.jpg'),
#   tensor([[0.0000, 0.0004, 0.0004, 0.0015, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000930.jpg'),
#   tensor([[1.0000e+00, 1.6846e-04, 9.9826e-05, 1.4404e-03, 1.9358e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000931.jpg'),
#   tensor([[1.0000e+00, 6.2744e-04, 1.0113e-03, 9.3262e-04, 1.2196e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000932.jpg'),
#   tensor([[0.0000, 0.0005, 0.0006, 0.0011, 0.0015]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000933.jpg'),
#   tensor([[0.0000, 0.0003, 0.0006, 0.0009, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000934.jpg'),
#   tensor([[0.0000, 0.0002, 0.0006, 0.0014, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000935.jpg'),
#   tensor([[0.0000, 0.0004, 0.0010, 0.0007, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000936.jpg'),
#   tensor([[1.0000e+00, 8.7158e-04, 8.2031e-04, 9.7656e-04, 1.1328e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000937.jpg'),
#   tensor([[1.0000e+00, 3.2043e-04, 8.5831e-04, 4.2820e-04, 1.2627e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000938.jpg'),
#   tensor([[1.0000e+00, 1.2451e-04, 6.3232e-04, 1.1133e-03, 1.1108e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000939.jpg'),
#   tensor([[1.0000e+00, 2.2461e-04, 3.3420e-04, 1.3452e-03, 1.7665e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000940.jpg'),
#   tensor([[0.0000, 0.0003, 0.0005, 0.0011, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000941.jpg'),
#   tensor([[0.0000e+00, 3.1738e-05, 4.2236e-04, 1.5234e-03, 1.3696e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000942.jpg'),
#   tensor([[0.0000, 0.0005, 0.0008, 0.0009, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000943.jpg'),
#   tensor([[0.0000, 0.0006, 0.0008, 0.0010, 0.0011]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000944.jpg'),
#   tensor([[1.0000e+00, 7.1045e-04, 9.1146e-04, 1.0693e-03, 1.1458e-03],
#           [1.0000e+00, 2.6855e-04, 8.5503e-04, 6.8359e-04, 1.2153e-03],
#           [1.0000e+00, 1.0742e-03, 9.3750e-04, 1.3599e-03, 1.1936e-03],
#           [1.0000e+00, 7.2021e-04, 1.1241e-03, 1.0547e-03, 1.3932e-03],
#           [1.0000e+00, 1.0449e-03, 1.1589e-03, 1.3135e-03, 1.4280e-03],
#           [1.0000e+00, 3.4180e-04, 1.1979e-03, 7.1289e-04, 1.4323e-03],
#           [1.0000e+00, 7.0801e-04, 1.3238e-03, 1.0132e-03, 1.5148e-03],
#           [1.0000e+00, 1.0010e-03, 1.3628e-03, 1.2866e-03, 1.6059e-03],
#           [1.0000e+00, 3.6621e-04, 1.4193e-03, 7.2021e-04, 1.6102e-03],
#           [1.0000e+00, 3.3936e-04, 1.6493e-04, 7.6172e-04, 5.2517e-04],
#           [0.0000e+00, 1.0913e-03, 4.5573e-04, 1.3599e-03, 9.5052e-04],
#           [1.0000e+00, 2.9053e-04, 5.2083e-04, 7.1289e-04, 9.3316e-04],
#           [1.0000e+00, 7.0801e-04, 5.3819e-04, 1.0986e-03, 9.3750e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000945.jpg'),
#   tensor([[1.0000e+00, 7.6660e-04, 5.2951e-04, 1.0132e-03, 7.2049e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000946.jpg'),
#   tensor([[1.0000e+00, 7.1289e-04, 9.0712e-04, 1.2158e-03, 1.2413e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000947.jpg'),
#   tensor([[1.0000e+00, 7.6416e-04, 1.3759e-03, 1.0889e-03, 1.6493e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000948.jpg'),
#   tensor([[0.0000, 0.0003, 0.0009, 0.0010, 0.0017]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000949.jpg'),
#   tensor([[1.0000e+00, 2.1484e-04, 3.2552e-04, 1.3232e-03, 1.2500e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000950.jpg'),
#   tensor([[0.0000, 0.0005, 0.0002, 0.0012, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000951.jpg'),
#   tensor([[1.0000e+00, 2.8564e-04, 2.3926e-04, 1.2427e-03, 1.2598e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000952.jpg'),
#   tensor([[1.0000e+00, 3.7842e-04, 5.5990e-04, 1.4429e-03, 1.3194e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000953.jpg'),
#   tensor([[1.0000e+00, 1.8311e-04, 7.8125e-05, 1.3330e-03, 2.0790e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000954.jpg'),
#   tensor([[0.0000, 0.0002, 0.0000, 0.0012, 0.0010]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000955.jpg'),
#   tensor([[1.0000e+00, 6.1279e-04, 1.2109e-03, 1.1621e-03, 1.5625e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000956.jpg'),
#   tensor([[0.0000, 0.0006, 0.0008, 0.0009, 0.0020]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000957.jpg'),
#   tensor([[1.0000e+00, 9.2285e-04, 5.6858e-04, 1.3403e-03, 9.2014e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000958.jpg'),
#   tensor([[0.0000, 0.0002, 0.0003, 0.0010, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000959.jpg'),
#   tensor([[1.0000e+00, 0.0000e+00, 9.2014e-04, 1.0742e-04, 1.2196e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000960.jpg'),
#   tensor([[0.0000, 0.0003, 0.0004, 0.0011, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000961.jpg'),
#   tensor([[0.0000e+00, 0.0000e+00, 7.8125e-05, 1.5576e-03, 1.6016e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000962.jpg'),
#   tensor([[1.0000e+00, 6.2744e-04, 8.2899e-04, 1.2646e-03, 1.1762e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000963.jpg'),
#   tensor([[0.0000, 0.0007, 0.0007, 0.0011, 0.0011]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000964.jpg'),
#   tensor([[1.0000e+00, 6.6650e-04, 1.2023e-03, 9.8877e-04, 1.4844e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000965.jpg'),
#   tensor([[0.0000, 0.0000, 0.0000, 0.0016, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000966.jpg'),
#   tensor([[1.0000e+00, 6.6895e-04, 5.6424e-04, 1.0742e-03, 9.2014e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000967.jpg'),
#   tensor([[0.0000, 0.0008, 0.0003, 0.0012, 0.0015]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000968.jpg'),
#   tensor([[1.0000e+00, 2.4902e-04, 3.6458e-04, 1.2378e-03, 1.8793e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000969.jpg'),
#   tensor([[1.0000e+00, 7.2510e-04, 5.8594e-04, 1.5381e-03, 1.6970e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000970.jpg'),
#   tensor([[1.0000e+00, 6.6650e-04, 7.0313e-04, 1.1523e-03, 9.7222e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000971.jpg'),
#   tensor([[1.0000e+00, 3.9063e-04, 7.7691e-04, 9.3018e-04, 1.0417e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000972.jpg'),
#   tensor([[0.0000, 0.0000, 0.0006, 0.0011, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000973.jpg'),
#   tensor([[1.0000e+00, 8.6914e-04, 3.6458e-04, 1.3501e-03, 6.3368e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000974.jpg'),
#   tensor([[1.0000e+00, 7.0312e-04, 6.6406e-04, 1.1426e-03, 9.0712e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000975.jpg'),
#   tensor([[0.0000, 0.0000, 0.0004, 0.0015, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000976.jpg'),
#   tensor([[1.0000e+00, 3.7842e-04, 7.8559e-04, 7.9102e-04, 1.0243e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000977.jpg'),
#   tensor([[0.0000, 0.0002, 0.0002, 0.0009, 0.0019]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000978.jpg'),
#   tensor([], size=(0, 5)),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000979.jpg'),
#   tensor([[0.0000, 0.0003, 0.0006, 0.0012, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000980.jpg'),
#   tensor([[1.0000e+00, 4.2725e-04, 7.9861e-04, 8.2275e-04, 1.0720e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000981.jpg'),
#   tensor([[0.0000, 0.0009, 0.0014, 0.0012, 0.0016]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000982.jpg'),
#   tensor([[1.0000e+00, 2.8809e-04, 2.5608e-04, 1.3208e-03, 1.4366e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000983.jpg'),
#   tensor([[1.0000e+00, 7.8613e-04, 9.6354e-04, 1.0327e-03, 1.1936e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000984.jpg'),
#   tensor([[1.0000e+00, 2.0996e-04, 3.5590e-04, 1.2549e-03, 1.6059e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000985.jpg'),
#   tensor([], size=(0, 5)),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000986.jpg'),
#   tensor([[0.0000, 0.0004, 0.0009, 0.0005, 0.0013]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000987.jpg'),
#   tensor([[0.0000, 0.0002, 0.0005, 0.0013, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000988.jpg'),
#   tensor([[0.0000, 0.0004, 0.0002, 0.0010, 0.0006]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000989.jpg'),
#   tensor([[0.0000e+00, 5.1270e-05, 0.0000e+00, 1.4160e-03, 1.5576e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000990.jpg'),
#   tensor([[1.0000e+00, 1.2207e-03, 5.6424e-04, 1.3599e-03, 9.7656e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000991.jpg'),
#   tensor([[0.0000, 0.0003, 0.0002, 0.0013, 0.0014]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000992.jpg'),
#   tensor([[0.0000, 0.0002, 0.0004, 0.0014, 0.0018]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000993.jpg'),
#   tensor([[1.0000e+00, 1.2207e-05, 4.2480e-04, 7.4707e-04, 1.0132e-03],
#           [1.0000e+00, 5.4687e-04, 7.1533e-04, 1.2109e-03, 1.1255e-03],
#           [1.0000e+00, 9.0332e-04, 4.8096e-04, 1.5601e-03, 1.0400e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000994.jpg'),
#   tensor([[1.0000e+00, 6.3477e-05, 1.5191e-04, 1.2622e-03, 1.6884e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000995.jpg'),
#   tensor([[0.0000e+00, 2.0752e-04, 6.6840e-04, 5.5420e-04, 1.1155e-03],
#           [0.0000e+00, 9.5215e-04, 5.9462e-04, 1.1035e-03, 8.3333e-04],
#           [1.0000e+00, 1.1890e-03, 8.2465e-04, 1.4087e-03, 1.1068e-03],
#           [1.0000e+00, 1.1841e-03, 1.0894e-03, 1.4819e-03, 1.4627e-03],
#           [1.0000e+00, 3.3203e-04, 1.1892e-03, 6.3477e-04, 1.6753e-03],
#           [0.0000e+00, 4.3945e-05, 1.0851e-03, 3.3691e-04, 1.6276e-03],
#           [1.0000e+00, 8.1299e-04, 1.1198e-03, 1.0181e-03, 1.4323e-03],
#           [0.0000e+00, 8.3984e-04, 8.6372e-04, 1.0718e-03, 1.1545e-03],
#           [1.0000e+00, 9.7900e-04, 1.1068e-03, 1.1646e-03, 1.4106e-03],
#           [0.0000e+00, 6.7627e-04, 1.0243e-03, 8.0322e-04, 1.2153e-03],
#           [1.0000e+00, 6.1035e-04, 1.1762e-03, 8.3984e-04, 1.5408e-03],
#           [0.0000e+00, 5.1270e-04, 1.0286e-03, 6.9580e-04, 1.2153e-03],
#           [1.0000e+00, 1.4111e-03, 1.0460e-03, 1.5576e-03, 1.2543e-03],
#           [1.0000e+00, 9.4727e-04, 7.9861e-04, 1.1328e-03, 1.0807e-03],
#           [1.0000e+00, 1.1426e-03, 1.0503e-03, 1.2671e-03, 1.3759e-03],
#           [1.0000e+00, 2.9053e-04, 1.1285e-03, 5.1758e-04, 1.4931e-03]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000996.jpg'),
#   tensor([[0.0000, 0.0006, 0.0005, 0.0013, 0.0012]], dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000997.jpg'),
#   tensor([[1.0000e+00, 6.9824e-04, 6.5104e-04, 9.3018e-04, 8.2031e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000998.jpg'),
#   tensor([[0.0000e+00, 2.4414e-06, 5.1215e-04, 4.5166e-04, 8.9410e-04]],
#          dtype=torch.float64),
#   0.0),
#  (PosixPath('/home/cmurphy/datasets/toma/box-detection-yolo/images/train/000000000999.jpg'),
#   tensor([[1.0000e+00, 2.8320e-04, 1.6927e-04, 1.3818e-03, 1.8012e-03]],
#          dtype=torch.float64),
#   0.0),
#  ...]
